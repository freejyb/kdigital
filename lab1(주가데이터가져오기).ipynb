# %% [markdown]
# 주가데이터 자져오기 시각화

# %%
pip install -U finance-datareader
# Out:
# Requirement already up-to-date: finance-datareader in c:\users\jyb\anaconda3\lib\site-packages (0.9.31)
# Requirement already satisfied, skipping upgrade: lxml in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (4.5.2)
# Requirement already satisfied, skipping upgrade: tqdm in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (4.47.0)
# Requirement already satisfied, skipping upgrade: requests>=2.3.0 in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (2.24.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.19.2 in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (1.0.5)
# Requirement already satisfied, skipping upgrade: requests-file in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.25.9)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\jyb\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\jyb\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.18.5)
# Requirement already satisfied, skipping upgrade: six in c:\users\jyb\anaconda3\lib\site-packages (from requests-file->finance-datareader) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.31'

# %%
import FinanceDataReader as fdr
# 삼성전자, 2018년
df = fdr.DataReader('005930', "2018")
import FinanceDataReader as fdr
df. head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2018-01-02  51380  51400  50780  51020  169485  0.001177
# 2018-01-03  52540  52560  51420  51620  200270  0.011760
# 2018-01-04  52120  52180  50640  51080  233909 -0.010461
# 2018-01-05  51300  52120  51200  52120  189623  0.020360
# 2018-01-08  52400  52520  51500  52020  167673 -0.001919

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2018")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
# 삼성전자, 2018년
df = fdr.DataReader('005930', "2018", "2020")
import FinanceDataReader as fdr
df. head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2018-01-02  51380  51400  50780  51020  169485  0.001177
# 2018-01-03  52540  52560  51420  51620  200270  0.011760
# 2018-01-04  52120  52180  50640  51080  233909 -0.010461
# 2018-01-05  51300  52120  51200  52120  189623  0.020360
# 2018-01-08  52400  52520  51500  52020  167673 -0.001919

# %%
import FinanceDataReader as fdr
import pandas as pd
df = fdr.DataReader('005930', "2018", "2020")
df.to_csv('se.csv', encoding='utf-8-sig')

# %%
port FinanceDataReader as fdr
import pandas as pd
df = fdr.DaataReader('005930', "2018", "2020")
# df.to_csv('se.csv', encoding='utf-8-sig')
df.to_excel('se.xlsx')
# Out:
#   File "<ipython-input-5-0180c7f1147c>", line 1
#     port FinanceDataReader as fdr
#          ^
# SyntaxError: invalid syntax

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2018", "2020")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2018", "2021")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2018-01-01", "2020-12-31")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
#애플주가(AAPL)
df = fdr.DataReader('AAPL', "2018")
df.tail()
# Out:
#              Close    Open    High     Low      Volume  Change
# Date
# 2021-06-22  133.98  132.09  134.08  131.64  74780000.0  0.0127
# 2021-06-23  133.70  133.87  134.31  133.24  60210000.0 -0.0021
# 2021-06-24  133.41  134.45  134.51  132.94  68710000.0 -0.0022
# 2021-06-25  133.11  133.46  133.89  132.81  70780000.0 -0.0022
# 2021-06-28  134.78  133.46  135.24  133.46  62110000.0  0.0125

# %%
import FinanceDataReader as fdr
#애플주가(AAPL)
df = fdr.DataReader('AAPL', "2018")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
#KOSPI(KS11)
df = fdr.DataReader('KS11', "2015")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
#다우지수(DJI)
df = fdr.DataReader('DJI', "2015")
df['Close'].plot()

# %%
# 환율 가져오기
import FinanceDataReader as fdr
#원달러환율(USD/KRW)
df = fdr.DataReader('USD/KRW', "1995")
df.head()
# Out:
#              Close    Open    High     Low  Change
# Date
# 1995-01-02  788.50  788.50  788.50  788.50  0.0000
# 1995-01-03  788.65  788.05  788.85  787.55  0.0002
# 1995-01-04  789.95  788.65  790.05  788.45  0.0016
# 1995-01-05  789.90  789.80  790.20  789.30 -0.0001
# 1995-01-06  791.55  789.75  791.65  789.65  0.0021

# %%
# 환율 시각화
import FinanceDataReader as fdr
#원달러환율(USD/KRW)
df = fdr.DataReader('USD/KRW', "1995")
df['Close'].plot()

# %%
#암호화폐가격 비트코인(빗썸)
import FinanceDataReader as fdr
df = fdr.DataReader('BTC/KRW', "2016")
df.head()
# Out:
#               Close     Open     High      Low   Volume  Change
# Date
# 2017-05-23  3206000  3104000  3281000  3081000  21580.0  0.0329
# 2017-05-24  4175000  3206000  4314000  3206000  34680.0  0.3022
# 2017-05-25  4199000  4175000  4840000  3102000  35910.0  0.0057
# 2017-05-26  3227000  4199000  4200000  2900000  36650.0 -0.2315
# 2017-05-27  3152000  3227000  3288000  2460000  33750.0 -0.0232

# %% [markdown]
# #암호화폐가격 비트코인(빗썸) 시각화
# import FinanceDataReader as fdr
# df = fdr.DataReader('BTC/KRW', "2016")
# df['Close'].plot()

# %% [raw]
# 마켓데이터 크롤링- 개별주식 가격데이터
# pandas_datareader + morningstar
# MultiIndex 가격 데이터와 차트 그리기

# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.5'

# %%
import pandas_datareader as pdr
pdr.__version__
# Out:
# '0.9.0'

# %% [markdown]
# 데이터 가져오기
# (Tiingo, Robinhood, Morningstar, IEX, 등)

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('005930', '2021-01-01', '2021-02-15')
fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2120">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="03457cf6-f7c6-4cda-98a8-1f4434d9ac20" data-root-id="2268"></div>

# %%
fdr.chart.plot(df, title='삼성전자(005930)')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2549">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6c43734d-89c5-411f-8329-d62d1ca7f4be" data-root-id="2697"></div>

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('005930', '2018-01-01', '2021-02-15')
fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3491">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="030a379f-c010-41ef-a213-facde1816092" data-root-id="3639"></div>
