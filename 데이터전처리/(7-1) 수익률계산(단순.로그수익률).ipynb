# %%
#데이터프레임에서 수익률 계산

# %%
import pandas as pd

data = {'삼성전자': [52200, 52300, 52900, 52000, 51700], 
           'LG전자': [68200, 67800, 68800, 67500, 66300]}
df = pd.DataFrame(data=data)
df
# Out:
#     삼성전자   LG전자
# 0  52200  68200
# 1  52300  67800
# 2  52900  68800
# 3  52000  67500
# 4  51700  66300

# %%
df.pct_change()
# Out:
#        삼성전자      LG전자
# 0       NaN       NaN
# 1  0.001916 -0.005865
# 2  0.011472  0.014749
# 3 -0.017013 -0.018895
# 4 -0.005769 -0.017778

# %%
df.pct_change() * 100
# Out:
#        삼성전자      LG전자
# 0       NaN       NaN
# 1  0.191571 -0.586510
# 2  1.147228  1.474926
# 3 -1.701323 -1.889535
# 4 -0.576923 -1.777778

# %% [markdown]
# ## 단순수익률과 로그수익률

# %%
import pandas as pd 
import yfinance as yf
import numpy as np

# %%
df_yahoo = yf.download('AAPL', 
                       start='2000-01-01', 
                       end='2010-12-31',
                       progress=False)

# %%
print(f'Downloaded {df_yahoo.shape[0]} rows of data.')

df_yahoo.head()
# Out:
# Downloaded 2767 rows of data.
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1999-12-31  0.901228  0.918527  0.888393  0.917969   0.789364  163811200
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.859423  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.786965  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.798481  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.729382  767972800

# %%
df = yf.download('AAPL', 
                 start='2000-01-01', 
                 end='2010-12-31',
                 progress=False)

df = df.loc[:, ['Adj Close']]
df.rename(columns={'Adj Close':'adj_close'}, inplace=True)
df.head()
# Out:
#             adj_close
# Date
# 1999-12-31   0.789364
# 2000-01-03   0.859423
# 2000-01-04   0.786965
# 2000-01-05   0.798481
# 2000-01-06   0.729382

# %%
df['simple_rtn']=df.adj_close.pct_change()
df['log_rtn'] = np.log(df.adj_close) - np.log(df.adj_close.shift(1)) 
df
# Out:
#             adj_close  simple_rtn   log_rtn
# Date
# 1999-12-31   0.789364         NaN       NaN
# 2000-01-03   0.859423    0.088754  0.085034
# 2000-01-04   0.786965   -0.084310 -0.088077
# 2000-01-05   0.798481    0.014633  0.014527
# 2000-01-06   0.729382   -0.086538 -0.090514
# ...               ...         ...       ...
# 2010-12-23   9.938018   -0.004798 -0.004809
# 2010-12-27   9.971185    0.003337  0.003332
# 2010-12-28   9.995453    0.002434  0.002431
# 2010-12-29   9.989920   -0.000554 -0.000554
# 2010-12-30   9.939864   -0.005011 -0.005023
#
# [2767 rows x 3 columns]

# %%
import numpy as np
np.exp(0.0058)
# Out:
# 1.0058168525658735

# %%
import numpy as np
(np.exp(-0.1029)-1)*100
# Out:
# -9.77828093103501

# %%
import numpy as np
(np.exp(-0.0441)-1)*100
# Out:
# -4.314173313809033

# %%
-0.103
