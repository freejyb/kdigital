# %% [markdown]
# # 1. 선형 결합

# %% [markdown]
# 선형 결합은 수학, 통계학, 머신러닝에서 매우 중요한 개념입니다.
#
# 선형 결합은 여러 개의 변수와 가중치가 곱해진 후, 이를 합산한 값을 의미합니다.

# %% [markdown]
# #### 벡터와 선형결합

# %%
import numpy as np

# 입력 벡터 (x)와 가중치 벡터 (w)
x = np.array([1, 2, 3])
w = np.array([0.5, 1.0, 1.5])

# 선형 결합 계산
linear_combination = np.dot(w, x)
print("선형 결합 결과:", linear_combination)
# Out:
# 선형 결합 결과: 7.0

# %%
# 여기서 
# 𝑥=[1,2,3]이고, 𝑤=[0.5,1.0,1.5]입니다.

# 선형 결합은 0.5×1+1.0×2+1.5×3=7.0으로 계산됩니다.

# %% [markdown]
# # 선형 회귀에서의 선형 결합

# %% [markdown]
# ##### 선형 회귀 모델에서는 입력 변수들과 가중치 간의 선형 결합으로 출력값을 예측합니다.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# 샘플 데이터 생성
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([3, 5, 7, 9, 11])  # y = 2x + 1

# 선형 회귀 모델 훈련
model = LinearRegression()
model.fit(X, y)

# 가중치와 절편 확인
print("가중치 (w):", model.coef_)
print("절편 (b):", model.intercept_)

# 예측
y_pred = model.predict(X)
print("예측 값:", y_pred)
# Out:
# 가중치 (w): [2.]
# 절편 (b): 1.0
# 예측 값: [ 3.  5.  7.  9. 11.]

# %% [markdown]
# ### 선형 모델 예시

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 데이터 생성
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = 2 * X.flatten() + 1  # y = 2x + 1

# 선형 회귀 모델 훈련
model = LinearRegression()
model.fit(X, y)

# 예측
y_pred = model.predict(X)

# 시각화
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Linear Fit')
plt.legend()
plt.title('Linear Model')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 다항 회귀 (비선형 모델)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# 모델 훈련
model_poly = LinearRegression()
model_poly.fit(X_poly, y)

# 예측
y_pred_poly = model_poly.predict(X_poly)

# 시각화
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred_poly, color='red', label='Polynomial Fit')
plt.legend()
plt.title('Non-linear Model (Polynomial Regression)')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 다항 회귀

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 데이터 생성
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 5, 10, 17, 26])

# 2차 다항 회귀 모델
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# 선형 회귀 모델 적용
model = LinearRegression()
model.fit(X_poly, y)
y_pred = model.predict(X_poly)

# 시각화
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Polynomial Fit (Degree 2)')
plt.title('Polynomial Regression (Non-linear Relationship)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # 2. 선형 변환 (Linear Transformation)

# %% [markdown]
# 정의
#
# 선형 변환은 벡터 공간에서 벡터를 다른 벡터로 변환하는 함수입니다.
#
# 이 변환은 선형성(linearity)을 만족해야 합니다

# %% [markdown]
# ### 1) 회전(rotation)

# %% [markdown]
# 코드 설명

# %%
# 원래 벡터들
# vectors: 원래의 2차원 벡터들을 정의합니다.
# 첫 번째 벡터는 [2, 1]입니다.
# 두 번째 벡터는 [1, 3]입니다.
# 벡터를 numpy 배열로 생성하여 사용

# %%
# 변환 행렬
# rotation_matrix: 90도 회전 행렬을 정의합니다.
# 이 행렬은 벡터를 시계 반대 방향으로 90도 회전시키는 역할을 합니다.

# %%
# 선형 변환 적용
# vectors.dot(rotation_matrix.T): 원래의 벡터들에 변환 행렬을 곱해줍니다.
# rotation_matrix.T: 전치 행렬을 사용해 행렬 곱셈을 수행합니다.
# numpy의 .dot() 메서드를 사용하여 행렬 곱셈을 수행합니다.
# 결과적으로 변환된 벡터가 생성됩니다. 이 벡터는 원래 벡터를 회전 행렬을 사용해 변환한 결과입니다.

# %%
# 원래 벡터와 변환된 벡터 시각화
# plt.figure(): 새로운 그림을 생성합니다.
# plt.quiver(): 벡터를 시각화하기 위해 quiver plot을 사용합니다.
# [0, 0]: 두 벡터의 시작점을 원점 (0, 0)으로 지정합니다.
# vectors[:, 0], vectors[:, 1]: 각각 x좌표와 y좌표를 지정합니다.
# vectors[:, 0]은 모든 벡터의 x 좌표 ([2, 1]).
# vectors[:, 1]은 모든 벡터의 y 좌표 ([1, 3]).
# angles='xy', scale_units='xy', scale=1: 벡터의 스케일 및 방향을 설정합니다.
# color='blue': 원래 벡터의 색상을 파란색으로 지정합니다.
# label='Original Vectors': 원래 벡터에 레이블을 지정합니다.
# 두 번째 plt.quiver():
# 변환된 벡터를 시각화하는 코드입니다.
# transformed_vectors[:, 0], transformed_vectors[:, 1]는 변환된 벡터들의 x좌표 및 y좌표입니다.
# 색상은 빨간색으로 지정하고, 레이블을 'Transformed Vectors'로 설정합니다.

# %%
# 벡터 시각화
# 1,plt.xlim(-4, 4) :x축의 범위를 설정합니다.
# 2. plt.ylim(-4, 4) : y축의 범위를 설정합니다.
# 3. plt.axhline(0, color='black', lw=0.5) : 수평선(horizontal line)을 그립니다.
# y = 0인 위치에 검정색의 수평선을 그립니다.
# lw=0.5는 선의 두께(linewidth)를 의미하며, 0.5로 설정하여 얇은 선을 그립니다.
# 이 수평선은 x축을 시각적으로 표시하여 그래프 해석을 쉽게 만듭니다.
# 4. plt.axvline(0, color='black', lw=0.5) : 수직선(vertical line)을 그립니다.
# x = 0인 위치에 검정색의 수직선을 그립니다.
# 이 수직선은 y축을 시각적으로 표시하여 그래프의 중심을 명확하게 보여줍니다.
# 5. plt.grid() : 그래프에 그리드(grid)를 추가합니다.
# 6. plt.gca().set_aspect('equal') : 그래프의 축 비율을 설정합니다.
# gca()**는 현재의 그래프 객체를 반환하는 함수이며, **.set_aspect('equal')**은 x축과 y축의 단위를 동일하게 설정합니다.
# 이 설정은 벡터가 기하학적으로 정확하게 표현되도록 하기 위해 중요합니다. 
# 예를 들어, 1단위가 x축과 y축에서 동일한 길이로 보이도록 설정하여 왜곡 없이 벡터의 크기와 방향을 이해할 수 있게 합니다.
# 7. plt.legend() : 범례(legend)를 추가합니다.
# plt.quiver()에서 지정한 label 값 ('Original Vectors'와 'Transformed Vectors')이 범례에 표시되어, 어떤 화살표가 원래 벡터인지, 어떤 화살표가 변환된 벡터인지를 알 수 있습니다.
# 8. plt.show() : 그래프를 화면에 표시합니다.
# 이 명령을 실행해야 그래프가 실제로 보이게 됩니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 원래 벡터들
vectors = np.array([[2, 1], [1, 3]])

# 변환 행렬 (90도 회전 행렬)
rotation_matrix = np.array([[0, -1], [1, 0]])

# 선형 변환 적용
transformed_vectors = vectors.dot(rotation_matrix.T)

# 원래 벡터와 변환된 벡터 시각화
plt.figure()
plt.quiver([0, 0], [0, 0], vectors[:, 0], vectors[:, 1], angles='xy', scale_units='xy', scale=1, color='blue', label='Original Vectors')
plt.quiver([0, 0], [0, 0], transformed_vectors[:, 0], transformed_vectors[:, 1], angles='xy', scale_units='xy', scale=1, color='red', label='Transformed Vectors')

plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.grid()
plt.gca().set_aspect('equal')
plt.legend()
plt.show()

# %%
# 코드 설명
# 벡터 데이터 생성:

# vectors는 2D 공간의 입력 벡터들입니다.
# origin은 벡터들이 시작하는 원점입니다.
# 변환 행렬 정의:

# transformation_matrix는 벡터를 변환하는 데 사용되는 행렬입니다.
# 이 예시에서는 행렬 를 사용하여 벡터를 확대하고 회전시킵니다.

#     선형 변환 적용:

# @ 연산자는 행렬 곱셈을 수행합니다.
# vectors @ transformation_matrix.T는 각 벡터에 변환 행렬을 적용한 결과입니다.
# 시각화:

# quiver 함수는 2D 벡터를 시각화합니다.
# 파란색 벡터는 변환 전의 원본 벡터, 빨간색 벡터는 변환 후의 벡터입니다.
# 그래프 설정:

# 축과 격자를 추가하고, 그래프의 제목과 레이블을 설정합니다.
# 출력 결과
# 그래프에는 **원본 벡터(파란색)**와 **변환된 벡터(빨간색)**가 표시됩니다.
# 변환된 벡터들은 확대되고 회전된 형태로 나타납니다.
# 이 코드는 선형 변환이 벡터의 크기와 방향을 어떻게 변경하는지 직관적으로 보여줍니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. 2D 벡터 데이터 생성
vectors = np.array([[1, 2], [2, 3], [-1, -1], [-2, -2]])
origin = np.zeros(vectors.shape)  # 원점 (0, 0)

# 2. 변환 행렬 정의 (확대와 회전을 나타냄)
transformation_matrix = np.array([[2, 1], [-1, 1]])

# 3. 선형 변환 적용
transformed_vectors = vectors @ transformation_matrix.T

# 4. 시각화
plt.figure(figsize=(10, 6))

# 원본 벡터 시각화 (파란색)
plt.quiver(*origin.T, vectors[:, 0], vectors[:, 1], color='blue', scale=5, label='Original Vectors')

# 변환된 벡터 시각화 (빨간색)
plt.quiver(*origin.T, transformed_vectors[:, 0], transformed_vectors[:, 1], color='red', scale=5, label='Transformed Vectors')

# 5. 그래프 설정
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid()
plt.legend()
plt.title('Linear Transformation of Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.gca().set_aspect('equal')

# 6. 그래프 출력
plt.show()

# %% [markdown]
# # 선형모델 사례

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# 샘플 데이터 생성
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([3, 6, 9, 12, 15])

# 선형 회귀 모델 훈련
model = LinearRegression()
model.fit(X, y)

# 예측
y_pred = model.predict(X)

# 시각화
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Linear Fit')
plt.legend()
plt.title('Linear Regression Example')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %% [markdown]
#  비선형 모델 (Non-linear Model)
#
# 개념
#
# 비선형 모델은 입력 변수와 출력 변수 간의 관계가 직선이 아닌 곡선형이라고 가정합니다.
#
# 입력 변수의 비선형 조합을 사용하여 복잡한 패턴을 학습할 수 있습니다

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([1, 4, 9, 16, 25])  # y = x^2

# 다항 특성 생성 (2차 다항식)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# 다항 회귀 모델 훈련
model = LinearRegression()
model.fit(X_poly, y)

# 예측
y_pred = model.predict(X_poly)

# 시각화
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Polynomial Fit (Degree 2)')
plt.legend()
plt.title('Polynomial Regression Example')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
