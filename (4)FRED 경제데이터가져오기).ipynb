# %% [markdown]
# ### Federal Reserve Economic Data : fred

# %%
# !pip install full-fred
# Out:
# Collecting full-fred
#   Using cached full_fred-0.0.9a3-py3-none-any.whl (47 kB)
# Requirement already satisfied: pandas in c:\users\jyb\anaconda3\lib\site-packages (from full-fred) (1.4.4)
# Requirement already satisfied: requests in c:\users\jyb\anaconda3\lib\site-packages (from full-fred) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->full-fred) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->full-fred) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->full-fred) (1.21.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (2022.9.14)
# Requirement already satisfied: six>=1.5 in c:\users\jyb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->full-fred) (1.16.0)
# Installing collected packages: full-fred
# Successfully installed full-fred-0.0.9a3

# %%
from full_fred.fred import Fred

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2022, 12, 31)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52 entries, 2010-01-01 to 2022-10-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     52 non-null     float64
# dtypes: float64(1)
# memory usage: 832.0 bytes

# %%
gdp
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.611
# 2010-04-01  14980.193
# 2010-07-01  15141.605
# 2010-10-01  15309.471
# 2011-01-01  15351.444
# 2011-04-01  15557.535
# 2011-07-01  15647.681
# 2011-10-01  15842.267
# 2012-01-01  16068.824
# 2012-04-01  16207.130
# 2012-07-01  16319.540
# 2012-10-01  16420.386
# 2013-01-01  16629.050
# 2013-04-01  16699.551
# 2013-07-01  16911.068
# 2013-10-01  17133.114
# 2014-01-01  17144.281
# 2014-04-01  17462.703
# 2014-07-01  17743.227
# 2014-10-01  17852.540
# 2015-01-01  17991.348
# 2015-04-01  18193.707
# 2015-07-01  18306.960
# 2015-10-01  18332.079
# 2016-01-01  18425.306
# 2016-04-01  18611.617
# 2016-07-01  18775.459
# 2016-10-01  18968.041
# 2017-01-01  19148.194
# 2017-04-01  19304.506
# 2017-07-01  19561.896
# 2017-10-01  19894.750
# 2018-01-01  20155.486
# 2018-04-01  20470.197
# 2018-07-01  20687.278
# 2018-10-01  20819.269
# 2019-01-01  21013.085
# 2019-04-01  21272.448
# 2019-07-01  21531.839
# 2019-10-01  21706.532
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
# 2022-10-01  26132.458

# %%
gdp.describe()
# Out:
#                 GDP
# count     52.000000
# mean   19186.611442
# std     3023.850239
# min    14764.611000
# 25%    16681.925750
# 50%    18693.538000
# 75%    21294.943000
# max    26132.458000

# %%
gdp.loc['2021-01-01']
# Out:
# GDP    22313.85
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
gdp.loc["2022-04-01"]
# Out:
# GDP    25248.476
# Name: 2022-04-01 00:00:00, dtype: float64

# %%
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

# %%
inflation
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962
# ...              ...       ...
# 2022-08-01   295.320   296.639
# 2022-09-01   296.539   298.339
# 2022-10-01   297.987   299.333
# 2022-11-01   298.598   300.261
# 2022-12-01   298.990   301.460
#
# [156 rows x 2 columns]

# %%
inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962

# %%
from pandas_datareader import wb
matches = wb.search('gdp.*capita.*const')

# %%
matches
# Out:
#                          id  \
# 716      6.0.GDPpc_constant
# 10654        NY.GDP.PCAP.KD
# 10656        NY.GDP.PCAP.KN
# 10658     NY.GDP.PCAP.PP.KD
# 10659  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 716    GDP per capita, PPP (constant 2011 internation...
# 10654                 GDP per capita (constant 2015 US$)
# 10656                      GDP per capita (constant LCU)
# 10658  GDP per capita, PPP (constant 2017 internation...
# 10659  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 716                  LAC Equity Lab
# 10654  World Development Indicators
# 10656  World Development Indicators
# 10658  World Development Indicators
# 10659         WDI Database Archives
#
#                                               sourceNote  \
# 716    GDP per capita based on purchasing power parit...
# 10654  GDP per capita is gross domestic product divid...
# 10656  GDP per capita is gross domestic product divid...
# 10658  GDP per capita based on purchasing power parit...
# 10659
#
#                                       sourceOrganization            topics
# 716         b'World Development Indicators (World Bank)'  Economy & Growth
# 10654  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10656  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10658  b'International Comparison Program, World Bank...  Economy & Growth
# 10659                                                b''

# %%
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2005, end=2008)

# %%
dat
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2008    42063.633052
#               2007    42097.435120
#               2006    41646.414637
#               2005    40989.526824
# Mexico        2008     9276.054837
#               2007     9288.162478
#               2006     9200.402581
#               2005     8925.236669
# United States 2008    53854.160612
#               2007    54299.617241
#               2006    53738.091725
#               2005    52789.731419

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 12 entries, ('Canada', '2008') to ('United States', '2005')
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NY.GDP.PCAP.KD  12 non-null     float64
# dtypes: float64(1)
# memory usage: 565.0+ bytes

# %%
import requests
import json
data = requests.get('https://api.stlouisfed.org/fred/series?series_id=GNPCA&api_key=43be4fc471782325cab7d47238bf8962&file_type=json')

# %%
data.json()
# Out:
# {'realtime_start': '2023-02-17',
#  'realtime_end': '2023-02-17',
#  'seriess': [{'id': 'GNPCA',
#    'realtime_start': '2023-02-17',
#    'realtime_end': '2023-02-17',
#    'title': 'Real Gross National Product',
#    'observation_start': '1929-01-01',
#    'observation_end': '2021-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Billions of Chained 2012 Dollars',
#    'units_short': 'Bil. of Chn. 2012 $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2022-09-29 07:45:54-05',
#    'popularity': 18,
#    'notes': 'BEA Account Code: A001RX\n\n'}]}

# %%
# !pip install full-fred
# Out:
# Requirement already satisfied: full-fred in c:\users\jyb\anaconda3\lib\site-packages (0.0.9a3)
# Requirement already satisfied: pandas in c:\users\jyb\anaconda3\lib\site-packages (from full-fred) (1.4.4)
# Requirement already satisfied: requests in c:\users\jyb\anaconda3\lib\site-packages (from full-fred) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->full-fred) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->full-fred) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->full-fred) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyb\anaconda3\lib\site-packages (from requests->full-fred) (2022.9.14)
# Requirement already satisfied: six>=1.5 in c:\users\jyb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->full-fred) (1.16.0)

# %%
# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.6, pytest-6.2.5, py-1.11.0, pluggy-1.0.0
# rootdir: C:\finance_data\깃허브(k디지털)\kdigital-main
# plugins: dash-1.21.0, html-3.1.1, metadata-1.11.0
# collected 0 items
#
# ============================ no tests ran in 0.08s ============================

# %%
from full_fred.fred import Fred
fred = Fred('example_key.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3364/2157078277.py in <module>
#       1 from full_fred.fred import Fred
# ----> 2 fred = Fred('example_key.txt')
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\full_fred\fred.py in __init__(self, api_key_file, observation_start, observation_end)
#      53         super().__init__()
#      54         if api_key_file is not None:
# ---> 55             self.set_api_key_file(api_key_file)
#      56         else:
#      57             self.api_key_file = api_key_file
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\full_fred\fred_base.py in set_api_key_file(self, api_key_file)
#      40         if not os.path.isfile(api_key_file):
#      41             e = "Can't find %s on path" % api_key_file
# ---> 42             raise FileNotFoundError(e)
#      43         self.api_key_file = api_key_file
#      44         return True
#
# FileNotFoundError: Can't find example_key.txt on path

# %%
fred.get_api_key_file()

# %%
fred.get_series_df('GDPPOT')

# %%
# 미국10년 국채수익률
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
