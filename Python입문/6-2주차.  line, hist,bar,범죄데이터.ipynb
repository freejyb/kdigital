# %% [markdown]
# # Line chart

# %% [markdown]
# ## 공통사항

# %%
# 선을 그리는 그래프
# 꺾은선 그래프
# 데이터가 시간, 순서 등에 따라 어떻게 변하는지를 보여주기 위해서 사용

# %% [markdown]
# ## 선챠트 (Line plot) 이해

# %%
# matplotlib.pyplot 모듈은 명령어 스타일로 동작하는 함수의 모음

## plot/ :  실제로 차트를 그리는 것이 아니라 내부적으로 그릴 준비를 하는 것
# 최종적으로 plt.show()를 하여야 차트가 시각화되어 보이게 됨 -->   plt.show()  


# NumPy 패키지의 random 모듈 (numpy.random) : random 모듈의 다양한 함수를 사용해서 특정 범위, 개수, 형태를 갖는 난수 생성에 활용
# random.randint() 함수는 [최소값, 최대값)의 범위에서 임의의 정수를 생성
# random.randn() 함수는 표준정규분포 (Standard normal distribution)로부터 샘플링된 난수를 반환
# random.standard_normal() 함수는 표준정규분포 (Standard normal distribution)로부터 샘플링된 난수를 반환

import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr

# %%
## plt.plot()을 이용하여 기본적으로 plot(x, y) 순서로 2개의 리스트(대괄호) 를 넣어주지만, 
# 만약 하나의 리스트만 넣을 경우 x는 자동적으로 0부터 할당

plt.plot([100, 120, 115, 125,135,140])
plt.show()

# %%
## plt.plot()을 이용하여 기본적으로 plot(x, y) 순서로 2개의 리스트로 입력

plt.plot(['2020','2021','2022','2023','2024', '2025'],[100, 120, 115, 125,135,140])
plt.show()


from matplotlib import font_manager,rc 
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
## Title and Axis Label, 차트 및 축 이름 설정하기

# %%
# plt.title() : 차트의 제목 설정
# plt.xlabel() : x축의 이름 설정
# plt.ylabel() : y축의 이름 설정

# %%
# 차트의 제목 설정

plt.title('전국 범죄발생 현황')
plt.plot(['2019','2020','2021','2022','2023', '2024'],[100, 120, 115, 125,135,140])
plt.show()

# %%
# 차트의 제목 설정

plt.title('전국 범죄발생 현황')
plt.xlabel('연도') 
plt.ylabel('범죄발생건수')

plt.plot(['2019','2020','2021','2022','2023', '2024'],[100, 120, 115, 125,135,140])

plt.show()

# %% [markdown]
# ##### 주의 사항 : 한글 깨짐 현상

# %%
# rc 함수를 이용해 글꼴 설정

from matplotlib import font_manager,rc 
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

plt.title('서울경찰청')
plt.plot(['2019','2020','2021','2022','2023','2024'],[100, 120, 115, 125, 200, 300])
plt.show()

# %%
# 차트의 제목 설정

plt.title('서울경찰청')
plt.plot(['2019','2020','2021','2022','2023','2024'],[100, 120, 115, 125, 200, 300])
plt.show()

# %%
# np.arange
# arange 함수: [start, stop) 에서 step 의 크기만큼 일정하게 떨어져 있는 숫자들을 array 형태로 반환해 주는 함수

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,50)
y = x*10

plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,50)
y = x+5

plt.plot(x,y)
plt.show()

# %%
## 스타일 지정 : Color (색깔) Line style (선 스타일), markers (점 모양)

# %%
# plot()에 보기가 편하도록 여러가지 스타일을 지정 가능
# 점의 색깔(Color),  선 스타일(Line style), 점의 모양(Markers),를 문자열로 쉽게 지정 가능

# Color (색깔) : 약자 또는 컬러이름 또는 ‘#RGB’로 지정가능
# b : blue
# g : green
# r : red
# y : yellow
# k : black


# Line style (선 스타일) : 문자 형태로 지정가능
# - : solid line
# -- : dashed line
# -. : dash-dot line
# : : dotted line


# Markers (점 모양): 문자 형태로 지정가능
# . : point marker
# o : circle marker
# ^ : triangle_up marker
# * : star marker
# x : x marker
# D : diamond marker


# 기본적으로 차트에 그려질 x, y 범위에 따라 자동으로 차트의 스케일이 정해진다.
# 하지만 xlim(), ylim()을 이용하여 스케일을 원하는 범위로 설정 가능.

# xlim() : x축 범위 설정
# ylim() : y축 범위 설정

# %%
#  라인 색깔 변경
# "b'	blue
# 'g'	green
# 'r'	red
# 'c'	cyan
# 'm'	magenta
# 'y'	yellow
# 'k'	black
# 'w'	white


from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,100)
y = x*5

plt.plot(x,y,'b')  
plt.show()

# %%
## 선 종류 변경하기
# '-'	solid line style
# '--'	dashed line style
# '-.'	dash-dot line style
# ':'	dotted line style
# '0'  : 원 마커

# %%
from matplotlib import pyplot as plt 
import numpy as np

x = np.arange(1,20)
y = x*2
plt.plot(x,y,'or')  # 원 마커 ‘o’,  붉은색 ‘r’로 표현 --> ‘or’로 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#데이터 생성
df1=pd.DataFrame({'X':[10,24,25,40,55],'Y':[150,160,170,180,177]})

#그래프생성

# figure 는 그래프가 그려지는 화면--> subplot 은 그래프이고,  한 figure 안에 여러개의 그래프를 그릴 수 있다. 
# 그래프는 보통 ax 라고 명명

fig,ax=plt.subplots(2,2)

ax[0,0].plot(df1['X'],df1['Y'],color='blue',linestyle='solid',marker='o')
ax[0,1].plot(df1['X'],df1['Y'],color='blue',linestyle='dotted',marker='o')
ax[1,0].plot(df1['X'],df1['Y'],color='blue',linestyle='dashed',marker='o')
ax[1,1].plot(df1['X'],df1['Y'],color='blue',linestyle='dashdot',marker='o')

#그래프 제목 추가
ax[0, 0].set_title("solid")
ax[0, 1].set_title("dotted")
ax[1, 0].set_title("dashed")
ax[1, 1].set_title("dashdot")

#간격설정
plt.subplots_adjust(wspace=0.2, hspace=0.4)

#그래프 출력
plt.show()

# %% [markdown]
# ## 범례 표시하기( legend)

# %%
# Legend, 차트의 범례 그리기 ( 여러개의 챠트가 존재하는 경우 설명표시를 하고픈 경우) 
# 그래프마다 라벨을 달고 이 라벨명을 출력할 수 있는 것
# legend()를 이용하여 각 데이터가 무엇인지 설명해주는 Legend(범례) 가능

# legend() : 차트에 각 데이터의 설명 추가

# 구글 : matplotlib 범례 혹은 matplotlib legend를 검색
#  plt. 뒤에 붙어있는 기능 중 범례로 언급되는 기능 이름을 찾고,
# 예제로 이동해서 plt.legend()를 찾는다.

# legend를 추가하려면 .plot 안에 label = "표시될 내용"을 추가해야한다.

## 레전드 : 그래프를 그릴때 여러개의 그래프를 같이 그리는 경우
# legend를 사용하기 위해서는 plt.plot에서 label 변수에 그래프의 이름을 정의
# plt.legend(‘위치')를 정함

# 범례 위치 결정해주기
# best
# upper right
# upper left
# lower left
# lower right
# right
# center left
# center right
# lower center
# upper center
# center

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10,0.1)
y = x*0.2
y2 = np.sin(x)

plt.plot(x,y,'b',label='서울') # 그래프 이름 정의
plt.plot(x,y2,'r',label='인천') # 그래프 이름 정의
plt.xlabel('시간') 
plt.ylabel('범죄발생건수')
plt.title('경찰청')# 그래프 제목 정의

plt.legend(loc='upper left')#  plt.legend(‘위치') 정의
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10,0.1)
y = x*0.2
y2 = np.sin(x)

plt.plot(x,y,'b',label='서울') # 그래프 이름 정의
plt.plot(x,y2,'r',label='인천') # 그래프 이름 정의
plt.xlabel('시간') 
plt.ylabel('범죄발생건수')
plt.title('경찰청')# 그래프 제목 정의

plt.legend(loc='lower center')#  plt.legend(‘위치') 정의
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10,0.1)
y = x*0.2
y2 = np.sin(x)

plt.plot(x,y,'b',label='서울') # 그래프 이름 정의
plt.plot(x,y2,'r',label='인천') # 그래프 이름 정의
plt.xlabel('시간') 
plt.ylabel('범죄발생건수')
plt.title('경찰청')# 그래프 제목 정의

plt.legend()#  plt.legend(‘위치') 정의
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('경찰청')
plt.ylabel('범죄거수')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4) # 범례 위치 지정
plt.tight_layout()
plt.show()

# %%
# legend를 사용하기 위해서는 plt.plot에서 label 변수에 그래프의 이름을 정의
# plt.legend(‘위치')를 정함
# tight_layout() :  axes 사이 간격을 적절하게 조정 가능

import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='lower right', ncol=4) # 범례 위치 지정

plt.tight_layout()
plt.show()

# %%
# #  rcParams 폰트 크기를 지정하는 방법
# plt.legend(fontsize= )범례 글꼴 크기를 지정하는 방법
# 범례의 prop속성

# plt.rc('legend', fontsize= )방법
# fontsize 는 포인트 단위를 갖는 정수
# xx--small
# x-small
# small
# medium
# large
# x-large
# xx-large

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='lower right', ncol=4) # 범례 위치 지정


plt.rc('legend', fontsize=12)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('경찰청')
plt.ylabel('범죄건수')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='lower right', ncol=4) # 범례 위치 지정


plt.rc('legend', fontsize='medium') # 범례 글씨 크기 옵션
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 타이틀과 라벨 명 지정하기

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,50)
y = x*5

plt.plot(x,y)
plt.xlabel('crime')
plt.ylabel('grade')
plt.title('seoul_police')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,50)
y = x*5

plt.plot(x,y)
plt.xlabel('crime')
plt.ylabel('grade')
plt.title('seoul_police')
plt.show()

# %% [markdown]
# ## 구간 확대/축소

# %%
# 그래프는 입력되는 x,y의 최소,최대 구간으로 자동으로 그려준다.
# 이 구간을 키우거나 줄이기 위해서 x,y의 구간을 정의 가능 
# x축은 plt.xlim(최소,최대),  y축은 plt.ylim(최소,최대)로 정의

##-> 가장 많이 쓰이는 기능들 (grid/xlim/ylim/xlabel/ylabel/xticks)

# xlim : 최대값(최소, 최대) 
# ylim : 최대값(최소, 최대)
# xlabel : x축 제목
# ylabel : y축 제목
# xticks : x축 간격/값 직접 지정

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(5,50)
y = x*5

plt.xlim(10,50) # x 범위 설정
plt.ylim(10,300) # y 범위 설정

plt.plot(x,y)
plt.xlabel('crime')
plt.ylabel('grade')
plt.title('seoul_police')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(5,50)
y = x*5

plt.xlim(0,50) 
plt.ylim(0,500)
plt.plot(x,y)
plt.xlabel('crime')
plt.ylabel('grade')
plt.title('seoul_police')
plt.show()

# %%
y1 = npr.normal(size = 50).cumsum()

# (왼쪽) default xlim, ylim
plt.subplot(121)
plt.plot(y1)
plt.title('서울경찰청')


# (오른쪽) xlim, ylim 사용자 설정
plt.subplot(122)
plt.plot(y1)
plt.xlim(0, 100)
plt.ylim(-10, 10)
plt.title('인천경찰청')
# Out:
# Text(0.5, 1.0, '인천경찰청')

# %% [markdown]
# # 서브플롯(subplot)

# %%
## 서브플롯 :   여러개의 그래프를 그리는 경우 사용
# 서브플롯은 그래프가 그려질 위치를 격자형으로 지정
# ==> plt.subplot(nrow,ncol,pos) 입력 사용 : 행의 개수, 열의 개수, 차트 위치 순으로 입력

# nrow,:  dataframe의 행의 수를 출력하는 함수
# ncol : column(열)의 개수 --> 변수의 개수를 세주는 함수
# pos : 현재 위치(좌표)
# nrow,ncol ==> 3,2 이면 3줄로, 가로는 2칸으로 된 그래프 plain 설정
# pos는 몇번째 plain에 그래프를 그릴지 지정하는데, 상단에서 부터 우측,아래 방향으로 1,2,3,4,5,6 순서

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10)
y1 = x*5
y2 = x*10
y3 = x*3
y4 = x*1

plt.subplot(3,1,1)
plt.plot(x,y1)
plt.subplot(3,1,1)
plt.plot(x,y2)
plt.subplot(3,1,1)
plt.plot(x,y3)
plt.subplot(3,1,1)
plt.plot(x,y4)

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10)
y1 = x*5
y2 = x*10
y3 = x*3
y4 = x*1

plt.subplot(2,1,1)  # 1면에
plt.plot(x,y1)
plt.subplot(2,1,1)
plt.plot(x,y2)
plt.subplot(2,1,1)
plt.plot(x,y3)
plt.subplot(2,1,1)
plt.plot(x,y4)

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10)

y1 = x*5
y2 = x*10
y3 = x*3
y4 = x*1
plt.subplot(2,1,1)  #  2,1 크기의 plain 을 만들어놓고 그래프를 위,아래로 두개를 그리는 경우
plt.plot(x,y1)
plt.subplot(2,1,2) # 두번째 면에
plt.plot(x,y2)
plt.subplot(2,1,2) # 두번째 면에
plt.plot(x,y3)
plt.subplot(2,1,2) # 두번째 면에
plt.plot(x,y4)
plt.show()

# %%
 # 2x2 plain으로 4개의 그래프를 그린 경우
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,20)
y1 = x*5
y2 = x*1
y3 = x*2
y4 = x*3
plt.subplot(2,2,1)
plt.plot(x,y1)
plt.subplot(2,2,2)
plt.plot(x,y2)
plt.subplot(2,2,3)
plt.plot(x,y3)
plt.subplot(2,2,4)
plt.plot(x,y4)
plt.show()

# %%
# 그래프 사이즈 변경
# plt.figure를 이용 figsize=(가로,세로)를 인자로 크기 조절

# figure 는 그래프가 그려지는 화면--> subplot 은 그래프이고,  한 figure 안에 여러개의 그래프를 그릴 수 있다. 
# 그래프는 보통 ax 라고 명명

# %%
import numpy as np
x = np.arange(1,20)
y1 = x*5
y2 = x*1
y3 = x*2
y4 = x*3
plt.figure(figsize=(10,5)) # 10x5 크기로 그래프 크기를 지정한 경우
plt.subplot(2,2,1)
plt.plot(x,y1)
plt.subplot(2,2,2)
plt.plot(x,y2)
plt.subplot(2,2,3)
plt.plot(x,y3)
plt.subplot(2,2,4)
plt.plot(x,y4)
plt.show()

# %%
import numpy as np
x = np.arange(1,20)
y1 = x*5
y2 = x*1
y3 = x*2
y4 = x*3
plt.figure(figsize=(20,5)) # 20x5 크기로 그래프 크기를 지정한 경우
plt.subplot(2,2,1)
plt.plot(x,y1)
plt.subplot(2,2,2)
plt.plot(x,y2)
plt.subplot(2,2,3)
plt.plot(x,y3)
plt.subplot(2,2,4)
plt.plot(x,y4)
plt.show()

# %% [markdown]
# # 히스토그램(histogram)
# ## plt.hist(객체, 구간)

# %%
# 표로 되어 있는 도수 분포를 정보 그림으로 나타낸 것
# 도수분포표를 그래프로 나타낸 것
# 잠정 : 자료가 모여 있는 위치나 자료의 분포에 관한 대략적인 정보를 한눈에 파악할 수 있다
# 단점 : 구체적인 수치정보를 쉽게 알아볼 수 없다.
# 특징 : 연속적인 데이터를 막대그래프로 표현한다.

# %%
# 라이블러리 불러오기

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 기본형

x = np.random.normal(size = 1000) # 

plt.hist(x) # 히스토그램챠트
plt.title('Seoul police') # 그래프 명칭 지정
plt.legend(['범죄']) # 범례
plt.show()

# %%
# seaborn을 활용한 데이터 출력

sns.histplot(x)
plt.title('Seoul police by seaborn')
plt.legend(['범죄'])
plt.show()

# %%
height = np.random.normal(size = 1000)


# 분할 구간의 개수를 지정해서 나누기
plt.subplot(3,1,1)
plt.hist(height, bins = 4)

# 구간을 자동으로 분할하기
plt.subplot(3,1,2)
plt.hist(height, bins = 'auto')

# 막대 넓이 조절
plt.subplot(3,1,3)
plt.hist(height, bins = 'auto', rwidth = 0.8)
# Out:
# (array([  1.,   0.,   1.,   3.,   6.,   4.,  23.,  37.,  45.,  72.,  99.,
#         118.,  94.,  97.,  90.,  82.,  69.,  60.,  43.,  23.,  14.,  14.,
#           5.]),
#  array([-3.72651473, -3.44528977, -3.16406481, -2.88283985, -2.60161489,
#         -2.32038993, -2.03916497, -1.75794001, -1.47671505, -1.19549009,
#         -0.91426513, -0.63304017, -0.35181521, -0.07059025,  0.21063471,
#          0.49185967,  0.77308463,  1.05430959,  1.33553455,  1.61675951,
#          1.89798447,  2.17920943,  2.46043439,  2.74165935]),
#  <BarContainer object of 23 artists>)

# %% [markdown]
# # 막대 그래프 (Bar chart)

# %%
# 히스토그램과 비슷한 형식의 막대 그래프
# plt.bar()를 이용 
# plt.hist()는 연속적인 데이터를 표현하고 plt.bar()는 카테고리를 나눌 수 있는 데이터를 표현
# plt.barh()를 이용하면 가로 막대 형식으로 출력 가능
# plt.bar)( : 세로 막대 차트

# %%
x = ['서울', '부산', '대구', '인천경찰청'] # x values
y = [32, 123, 53, 11] # height

plt.bar(x,y)
plt.title('police')
plt.xlabel('지방경찰청')
plt.ylabel('검거실적')
plt.legend(['지방경찰청별 검거실적'])
plt.show()

# %%
# seaborn  사용

sns.barplot(x=x,y=y)
plt.title('police')
plt.xlabel('지방경찰청')
plt.ylabel('검거실적')
plt.legend(['지방경찰정별 검거실적'])
plt.show()
