# %% [markdown]
# #  데이터 시각화

# %% [markdown]
# # matplotlib 이용
# ###Tutorials :  https://matplotlib.org/stable/tutorials/index.html

# %%
# matplotlib는 파이썬에서 2차원 그래프를 그릴 때 가장 널리 사용되는 라이브러리

# seaborn : Matplotlib을 기반으로 다양한 색상 테마와 통계용 차트 등의 기능을 추가한 시각화 패키지(: http://seaborn.pydata.org/)
# Plotly : https://plotly.com/python/

# %%
# matplotlib의 pyplot 모듈 :  그래프를 그리는 기능을 제공
# pyplot 모듈 사용 : 해당 모듈을 임포트
# https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py

import matplotlib.pyplot as plt

# %%
# matplotlib 라이브러리의 pyplot 모듈은 그래프를 그리는 데 사용되는 다양한 함수 포함
# plot 함수는 값을 서로 연결해서 라인 형태의 그래프를 그리는 함수

# %%
# Plot Type	Methods  	Description
# 기본 그래프
#     plot(x,y)	basic x-y line plot
#     scatter(x,y)	scatter plot
#      bar(x, height), barh(x, height)	bar plot/ horizental bar plot

# %%
# 통계관련 그래프
# hist(x)     	히스토그램
# hist2d(x, y)	2차원 히스토그램
# boxplot(x)	상자그림
# errorbar(x, y, yerr, xerr)	error-bar plot
# violinplot	boxplot과 비슷하게 데이터의 확률밀도를 시각화
# pie(x)	원그래프
# jointplot	Scatterplot, 산점도, 두 수치형 컬럼의 자료를 평면에 보여줌
# regplot	Regression plot
# pairplot	Pairplot
# swarmplot	범주형자료의 scatterplot
# factorplot	범주형자료를 시각화

# %%
# 옵션
# lines (style, color, width …),
# markers (size, shape, colors …),
# labels for legend,

# %%
# y축 값 1, 2, 3, 4, 5를 지나는 직선이 그려진 것을 확인
# plot 함수를 호출할 때 x 축 값을 따로 지정하지 않으면 자동으로 실숫값이 할당
# show 함수를 호출하면  그래프 출력
# plot 함수에서 y축 값이 5개, 대응하는 x축 값은 0.0, 1.0, 2.0, 3.0, 4.0/

plt.plot([1, 2, 3, 4, 5])
plt.show()

# %%
 # plot을 사용해서 그래프 그리기
# plot 함수는 x축 값과 y축 값을 동시에 받을 수도 있다. 
#  y=x2 (x>=0) 그래프는 다음과 같이 그릴 수 있다.

# %%
x = range(0, 100)
y = [a*a for a in x]
plt.plot(x, y)

# %%
x = range(0, 100)
y = [a*a for a in x]
plt.plot(x, y, 'ro')
# plot 함수에서 'ro' 인자를 통해 그래프의 색상과 스타일을 변경한 것
# 'ro' 인자에서 'r'은 red를 의미,  'o'는 그래프의 마커 모양을 의미

# %%
# matplotlib의 주요 색상
# b	blue(파란색),g	green(녹색),r	red(빨간색),c	cyan(청록색),m	magenta(마젠타색),y	yellow(노란색),k	black(검은색),w	white(흰색)

# %%
# matplotlib의 주요 마커
# o	circle(원),v	triangle_down(역 삼각형),^	triangle_up(삼각형),s	square(네모),+	plus(플러스),.	point(점)

# %%
 # legend loc 파라미터 옵션
# ‘best’	0
# ‘upper right’	1
# ‘upper left’	2
# ‘lower left’	3
# ‘lower right’	4
# ‘right’	5
# ‘center left’	6
# ‘center right’	7
# ‘lower center’	8
# ‘upper center’	9
# ‘center’	10

# %%
x = range(0, 100)
y = [a*a for a in x]
plt.plot(x, y, 'yo')

# %%
x = range(0, 100)
y = [a*a for a in x]
plt.plot(x, y, 'k.')

# %%
# 한 화면에 여러 개의 그래프 그리기
# figure 함수를 통해 Figure 객체를 먼저 만든 후 
# add_subplot 메서드를 통해 그리려는 그래프 개수만큼 subplot을 만든다.

# %%
# subplot의 개수는 add_subplot 메서드의 인자를 통해 조정 가능
# 만약 (2, 1, 1)은 2x1(행x열)의 subplot을 생성한다는 의미이고 세 번째 인자 1은 생성된 두 개의 subplot 중 첫 번째 subplot을 의미 
# 마찬가지로 (2, 1, 2)는 2x1 subplot에서 두 번째 subplot을 의미

# %%
# 변수 명명 : ax1, ax2라는 변수를 통해 생성된 객체 (Axes 용어)

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
plt.show()
# Figure 안에 두 개의 subplot이 존재하는데, 행 방향으로 2개, 열 방향으로는 1개의 subplot이 위치함을 확인

# %%
#  2x1 subplot 
# add_subplot 메서드의 인자를 변경해 1x2 형태의 subplot을 만드는 경우
#1x2 형태의 subplot이 생성되는 것을 확인

fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

x = range(0, 100)
y = [a*a for a in x]

# bar 함수는 pyplot 모듈에 있는 함수로 막대그래프를 그리는 데 사용
ax1.plot(x, y)
ax2.bar(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(200)
y1 = np.random.randn(200) # N(0,1)
y2 = y1 + np.random.randn(200)/2 # N(0,1)

# %%
#plt.figure(figsize=(8,5))
plt.plot(x, y1)
plt.title("plot")
plt.xlabel("x")
plt.ylabel("y1")
# Out:
# Text(0, 0.5, 'y1')

# %%
# 산점도 그리기 
#plt.figure(figsize=(8,7))
plt.scatter(y1, y2)

# %%
# 히스토그램 
plt.hist(x, bins=10, density=True)
# bins: 막대의 개수
plt.hist([s1,s2], label=['sepal_length', 'sepal_width'])
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8144/2890009178.py in <module>
#       2 plt.hist(x, bins=10, density=True)
#       3 # bins: 막대의 개수
# ----> 4 plt.hist([s1,s2], label=['sepal_length', 'sepal_width'])
#       5 plt.legend()
#
# NameError: name 's1' is not defined
