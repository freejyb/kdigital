# %% [markdown]
# ## FRED 경제데이터 가져오기
# ### FRED : Federal Reserve Economic Data

# %% [markdown]
# ##### https://en.wikipedia.org/wiki/Federal_Reserve_Economic_Data

# %% [markdown]
# #### https://fred.stlouisfed.org

# %% [markdown]
# ### https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %%
# FRED(Federal Reserve Economic Data) 세인트루이스 연준 관리 경제통계 데이터베이스
# 각 항목별 티커를 찾는 방법
# FRED 웹사이트(https://fred.stlouisfed.org/) 에서 원하는 데이터를 검색
# /series/ 다음에 위치하는 DEXKOUS가 해당 항목의 티커

# %% [markdown]
# ##### 미국 GDP(GDP)

# %%
# 미국 GDP(GDP)
import pandas_datareader as pdr

data1 = pdr.DataReader('GDP', 'fred', '2000-01-01')
data1.head()
# Out:
#                   GDP
# DATE
# 2000-01-01  10002.179
# 2000-04-01  10247.720
# 2000-07-01  10318.165
# 2000-10-01  10435.744
# 2001-01-01  10470.231

# %%
# 미국 GDP(GDP)
import pandas_datareader as pdr

data1 = pdr.DataReader('GDP', 'fred', '1990-01-01')
data1.head(10)
# Out:
#                  GDP
# DATE
# 1990-01-01  5872.701
# 1990-04-01  5960.028
# 1990-07-01  6015.116
# 1990-10-01  6004.733
# 1991-01-01  6035.178
# 1991-04-01  6126.862
# 1991-07-01  6205.937
# 1991-10-01  6264.540
# 1992-01-01  6363.102
# 1992-04-01  6470.763

# %%
import pandas_datareader as pdr

data2 = pdr.DataReader('T10Y2Y', 'fred', '2000-01-01')
data2.head(20)
# Out:
#             T10Y2Y
# DATE
# 2000-01-03    0.20
# 2000-01-04    0.19
# 2000-01-05    0.24
# 2000-01-06    0.22
# 2000-01-07    0.21
# 2000-01-10    0.19
# 2000-01-11    0.22
# 2000-01-12    0.23
# 2000-01-13    0.23
# 2000-01-14    0.25
# 2000-01-17     NaN
# 2000-01-18    0.28
# 2000-01-19    0.27
# 2000-01-20    0.30
# 2000-01-21    0.31
# 2000-01-24    0.26
# 2000-01-25    0.26
# 2000-01-26    0.24
# 2000-01-27    0.17
# 2000-01-28    0.08

# %%
import matplotlib.pyplot as plt
data2.plot(figsize=(10, 6))
plt.show()

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2022, 6, 27)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2020-01-01 to 2022-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     10 non-null     float64
# dtypes: float64(1)
# memory usage: 160.0 bytes

# %%
gdp
# Out:
#                   GDP
# DATE
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476

# %%
gdp.head(10)
# Out:
#                   GDP
# DATE
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476

# %%
# GDP 기초통계량 
gdp.describe()
# Out:
#                 GDP
# count     10.000000
# mean   22749.117800
# std     1759.417449
# min    19636.731000
# 25%    21579.700500
# 50%    22680.392000
# 75%    24149.445750
# max    25248.476000

# %%
gdp.loc['2021-01-01']
# Out:
# GDP    22313.85
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
# 여러 국가 가져오기
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2015, end=2020)
dat
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2020    42258.691017
#               2019    45109.244486
#               2018    44917.483728
#               2017    44325.488337
#               2016    43536.913403
#               2015    43596.135537
# Mexico        2020     8922.612472
#               2019     9819.532914
#               2018     9945.776845
#               2017     9842.400712
#               2016     9751.569083
#               2015     9616.645558
# United States 2020    58060.313948
#               2019    60687.232258
#               2018    59600.053098
#               2017    58215.411628
#               2016    57292.538783
#               2015    56762.729452

# %%
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2015, end=2020)
print(dat)
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2020    42258.691017
#               2019    45109.244486
#               2018    44917.483728
#               2017    44325.488337
#               2016    43536.913403
#               2015    43596.135537
# Mexico        2020     8922.612472
#               2019     9819.532914
#               2018     9945.776845
#               2017     9842.400712
#               2016     9751.569083
#               2015     9616.645558
# United States 2020    58060.313948
#               2019    60687.232258
#               2018    59600.053098
#               2017    58215.411628
#               2016    57292.538783
#               2015    56762.729452

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 18 entries, ('Canada', '2020') to ('United States', '2015')
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NY.GDP.PCAP.KD  18 non-null     float64
# dtypes: float64(1)
# memory usage: 641.0+ bytes

# %% [markdown]
# ##### 인플레이션

# %%
# 인플레이션
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)
inflation
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2020-01-01   258.682   266.418
# 2020-02-01   259.007   267.083
# 2020-03-01   258.165   266.916
# 2020-04-01   256.094   265.771
# 2020-05-01   255.944   265.606
# 2020-06-01   257.217   266.088
# 2020-07-01   258.543   267.552
# 2020-08-01   259.580   268.662
# 2020-09-01   260.190   269.152
# 2020-10-01   260.352   269.332
# 2020-11-01   260.721   269.816
# 2020-12-01   261.564   269.984
# 2021-01-01   262.200   270.114
# 2021-02-01   263.346   270.522
# 2021-03-01   265.028   271.347
# 2021-04-01   266.727   273.669
# 2021-05-01   268.599   275.715
# 2021-06-01   270.955   277.922
# 2021-07-01   272.184   278.794
# 2021-08-01   273.092   279.306
# 2021-09-01   274.214   280.017
# 2021-10-01   276.590   281.705
# 2021-11-01   278.524   283.179
# 2021-12-01   280.126   284.770
# 2022-01-01   281.933   286.431
# 2022-02-01   284.182   287.878
# 2022-03-01   287.708   288.811
# 2022-04-01   288.663   290.455
# 2022-05-01   291.474   292.289
# 2022-06-01   295.328   294.354

# %%
inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2020-01-01   258.682   266.418
# 2020-02-01   259.007   267.083
# 2020-03-01   258.165   266.916
# 2020-04-01   256.094   265.771
# 2020-05-01   255.944   265.606

# %%
from pandas_datareader import wb
matches = wb.search('gdp.*capita.*const')
matches

# %%
import requests
import json
data = requests.get('https://api.stlouisfed.org/fred/series?series_id=GNPCA&api_key=43be4fc471782325cab7d47238bf8962&file_type=json')

# %%
data.json()
# Out:
# {'realtime_start': '2022-09-30',
#  'realtime_end': '2022-09-30',
#  'seriess': [{'id': 'GNPCA',
#    'realtime_start': '2022-09-30',
#    'realtime_end': '2022-09-30',
#    'title': 'Real Gross National Product',
#    'observation_start': '1929-01-01',
#    'observation_end': '2021-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Billions of Chained 2012 Dollars',
#    'units_short': 'Bil. of Chn. 2012 $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2022-09-29 07:45:54-05',
#    'popularity': 19,
#    'notes': 'BEA Account Code: A001RX\n\n'}]}

# %%
# datapungi_fed  설치 필요
pip install datapungi_fed
# Out:
#   File "C:\Users\JYB\AppData\Local\Temp/ipykernel_14204/3726497070.py", line 2
#     pip install datapungi_fed
#         ^
# SyntaxError: invalid syntax

# %%
# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.6, pytest-6.2.5, py-1.11.0, pluggy-1.0.0
# rootdir: C:\finance_data\파이썬 입문(ansan)
# plugins: dash-1.21.0, html-3.1.1, metadata-1.11.0
# collected 0 items
#
# ============================ no tests ran in 0.02s ============================

# %% [markdown]
# ### FRED에서 API 경제데이터 가져오기

# %%
# 설치하기
# !pip install fredapi
# Out:
# Collecting fredapi
#   Downloading https://files.pythonhosted.org/packages/bc/9d/48187f2094be555d650ea514d8269d7b222eeeb776addcae06dcf5d9c519/fredapi-0.5.0-py3-none-any.whl
# Requirement already satisfied: pandas in c:\programdata\miniconda3\lib\site-packages (from fredapi) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\miniconda3\lib\site-packages (from pandas->fredapi) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\lib\site-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\programdata\miniconda3\lib\site-packages (from pandas->fredapi) (1.21.6)
# Requirement already satisfied: six>=1.5 in c:\programdata\miniconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->fredapi) (1.12.0)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.5.0

# %%
# API 발급을 위해서 회원가입 주석

# %%
from fredapi import Fred
fred = Fred(api_key='fd1643976833c89506544ff62efd7f70')
data = fred.get_series('GDP')

# %%
data = fred.get_series_first_release('GDP')
data.tail(10)
# Out:
# date
# 2020-01-01     21537.94
# 2020-04-01    19408.759
# 2020-07-01    21157.635
# 2020-10-01    21479.529
# 2021-01-01    22048.894
# 2021-04-01    22722.581
# 2021-07-01    23173.496
# 2021-10-01    23992.355
# 2022-01-01    24382.683
# 2022-04-01    24851.809
# Name: value, dtype: object

# %%
data = fred.get_series_latest_release('GDP')
data
# Out:
# 1946-01-01          NaN
# 1946-04-01          NaN
# 1946-07-01          NaN
# 1946-10-01          NaN
# 1947-01-01      243.164
#                 ...
# 2021-04-01    23046.934
# 2021-07-01    23550.420
# 2021-10-01    24349.121
# 2022-01-01    24740.480
# 2022-04-01    25248.476
# Length: 306, dtype: float64

# %%
fred.get_series_as_of_date('GDP', '6/1/2019')
# Out:
#      realtime_start       date      value
# 0        1992-12-22 1946-01-01      199.7
# 1        1996-01-19 1946-01-01        NaT
# 2        1997-05-07 1946-01-01      210.4
# 3        1999-10-28 1946-01-01        NaT
# 4        1992-12-22 1946-04-01      207.7
# ...             ...        ...        ...
# 3017     2018-12-21 2018-07-01  20658.204
# 3022     2019-02-28 2018-10-01  20891.367
# 3023     2019-03-28 2018-10-01   20865.14
# 3028     2019-04-26 2019-01-01  21062.691
# 3029     2019-05-30 2019-01-01  21048.839
#
# [2906 rows x 3 columns]

# %%
df = fred.get_series_all_releases('GDP')
df.tail()
# Out:
#      realtime_start       date      value
# 3093     2022-06-29 2022-01-01  24386.734
# 3094     2022-09-29 2022-01-01   24740.48
# 3095     2022-07-28 2022-04-01  24851.809
# 3096     2022-08-25 2022-04-01  24882.878
# 3097     2022-09-29 2022-04-01  25248.476

# %%
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2017-10-01  2.36
# 2017-11-01  2.35
# 2017-12-01  2.40
# 2018-01-01  2.58
# 2018-02-01  2.86
# 2018-03-01  2.84
# 2018-04-01  2.87
# 2018-05-01  2.98
# 2018-06-01  2.91
# 2018-07-01  2.89
# 2018-08-01  2.89
# 2018-09-01  3.00
# 2018-10-01  3.15
# 2018-11-01  3.12
# 2018-12-01  2.83
# 2019-01-01  2.71
# 2019-02-01  2.68
# 2019-03-01  2.57
# 2019-04-01  2.53
# 2019-05-01  2.40
# 2019-06-01  2.07
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# 2019-12-01  1.86
# 2020-01-01  1.76
# 2020-02-01  1.50
# 2020-03-01  0.87
# 2020-04-01  0.66
# 2020-05-01  0.67
# 2020-06-01  0.73
# 2020-07-01  0.62
# 2020-08-01  0.65
# 2020-09-01  0.68
# 2020-10-01  0.79
# 2020-11-01  0.87
# 2020-12-01  0.93
# 2021-01-01  1.08
# 2021-02-01  1.26
# 2021-03-01  1.61
# 2021-04-01  1.64
# 2021-05-01  1.62
# 2021-06-01  1.52
# 2021-07-01  1.32
# 2021-08-01  1.28
# 2021-09-01  1.37
# 2021-10-01  1.58
# 2021-11-01  1.56
# 2021-12-01  1.47
# 2022-01-01  1.76
# 2022-02-01  1.93
# 2022-03-01  2.13
# 2022-04-01  2.75
# 2022-05-01  2.90
# 2022-06-01  3.14
# 2022-07-01  2.90
# 2022-08-01  2.90

# %%
# 날짜는 datetime 패키지를 사용하여 지정
# 또는 문자열을 바로 사용해도 된다. 

import pandas_datareader.data as web

import datetime

start = datetime.datetime(2010, 1, 1)

end = datetime.datetime(2020, 12, 31)

gdp = web.DataReader('GDP', 'fred', start, end)

gdp.loc['2020-01-01']
# Out:
# GDP    21538.032
# Name: 2020-01-01 00:00:00, dtype: float64

# %% [markdown]
# ##### 데이터 코드에 리스트를 넣으면 여러개의 데이터를 동시에

# %%
# Multiple series:
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962
