# %% [markdown]
# # 금융데이터 수집하기

# %% [markdown]
# # # 데이터 수집 방법.(주가 등)
# #### 1. FinanceDataReader
# #### 2. pandas_datareader
# #### 3. yfinance
# #### 4. pykrx

# %% [markdown]
# ### 1. FinanceDataReader
# ### https://financedata.github.io/posts/finance-data-reader-users-guide.html

# %%
# 1. FinanceDataReader ;
# 현재 시점의 증권시장별 상장종목을 가져올 수 있음
# 종목코드, 시장, 종목명, 섹터, 산업군, 상장일, 결산월 등 
# 상장폐지 종목도 조회 가능

# %% [markdown]
# #### FinanceDataReader 설치하기

# %%
# !pip install -U finance-datareader
# Out:
# 파일 C:\Users\JYB\AppData\Local\Microsoft\WindowsApps\pip.exe을(를) 찾을 수 없습니다.

# %% [markdown]
# #### FinanceDataReader 를 fdr 별칭으로 가져오기

# %%
import FinanceDataReader as fdr

# %%
# 버젼 확인하기
fdr.__version__
# Out:
# '0.9.31'

# %% [markdown]
# ##### 데이터 가져오기

# %%
# 시장별 종목리스트를 가져오기 (최근일 기준)
# 코스피, 코스닥, 코넥스 전체 : 'KRX'

import FinanceDataReader as fdr

stocks = fdr.StockListing('KRX') 
stocks

stocks.head()
# Out:
#    Symbol  Market         Name    Sector     Industry ListingDate SettleMonth  \
# 0  060310  KOSDAQ           3S  전자부품 제조업  반도체 웨이퍼 캐리어  2002-04-23         03월
# 1  105190   KOSPI      ACE 200       NaN          NaN         NaT         NaN
# 2  332500   KOSPI    ACE 200TR       NaN          NaN         NaT         NaN
# 3  385590   KOSPI   ACE ESG액티브       NaN          NaN         NaT         NaN
# 4  380340   KOSPI  ACE Fn5G플러스       NaN          NaN         NaT         NaN
#
#   Representative              HomePage Region
# 0            김세완  http://www.3sref.com  서울특별시
# 1            NaN                   NaN    NaN
# 2            NaN                   NaN    NaN
# 3            NaN                   NaN    NaN
# 4            NaN                   NaN    NaN

# %%
len(stocks)
# Out:
# 7629

# %%
# 시장별 데이터 가져오기 : 'KOSPI', 'KODAQ', 'KONEX'
stocks_kospi = fdr.StockListing('KOSPI') 
# 앞 5개 뒷부분 5개 보여준다.
stocks_kospi
# Out:
#       Symbol Market              Name Sector Industry ListingDate SettleMonth  \
# 1     105190  KOSPI           ACE 200    NaN      NaN         NaT         NaN
# 2     332500  KOSPI         ACE 200TR    NaN      NaN         NaT         NaN
# 3     385590  KOSPI        ACE ESG액티브    NaN      NaN         NaT         NaN
# 4     380340  KOSPI       ACE Fn5G플러스    NaN      NaN         NaT         NaN
# 5     226380  KOSPI     ACE Fn성장소비주도주    NaN      NaN         NaT         NaN
# ...      ...    ...               ...    ...      ...         ...         ...
# 7655  435540  KOSPI   히어로즈 TDF2040액티브    NaN      NaN         NaT         NaN
# 7656  435550  KOSPI   히어로즈 TDF2050액티브    NaN      NaN         NaT         NaN
# 7657  437550  KOSPI  히어로즈 글로벌리츠이지스액티브    NaN      NaN         NaT         NaN
# 7658  419890  KOSPI   히어로즈 단기채권ESG액티브    NaN      NaN         NaT         NaN
# 7659  429870  KOSPI     히어로즈 리츠이지스액티브    NaN      NaN         NaT         NaN
#
#      Representative HomePage Region
# 1               NaN      NaN    NaN
# 2               NaN      NaN    NaN
# 3               NaN      NaN    NaN
# 4               NaN      NaN    NaN
# 5               NaN      NaN    NaN
# ...             ...      ...    ...
# 7655            NaN      NaN    NaN
# 7656            NaN      NaN    NaN
# 7657            NaN      NaN    NaN
# 7658            NaN      NaN    NaN
# 7659            NaN      NaN    NaN
#
# [5923 rows x 10 columns]

# %% [markdown]
# #### 데이터 탐색하기 (EDA : Exploratory Data Analysis)

# %%
# 탐색적 데이터 분석(EDA)이란?
# 데이터(Raw data)를 가지고 유연하게 데이터를 탐색
# 데이터의 특징과 구조로부터 얻은 정보를 바탕으로 통계모형을 만드는 분석방법
# 기술통계 활용 : 기초통계량,  시각화

# %%
# 데이터 행과 열을 확인해보기
# shape
stocks_kospi = fdr.StockListing('KOSPI') 
stocks_kospi.shape
# Out:
# (6309, 10)

# %%
# 데이터 정보 확인해보기
# info
stocks_kospi = fdr.StockListing('KOSPI') 
stocks_kospi.info
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18932/2220067795.py in <module>
#       1 # 데이터 정보 확인해보기
#       2 # info
# ----> 3 stocks_kospi = fdr.StockListing('KOSPI')
#       4 stocks_kospi.info
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\FinanceDataReader\data.py in StockListing(market)
#      60         return NaverStockListing(market).read()
#      61     if market in [ 'KRX', 'KOSPI', 'KOSDAQ', 'KONEX']:
# ---> 62         return KrxStockListing(market).read()
#      63     if market in [ 'KRX-DELISTING' ]:
#      64         return KrxDelisting(market).read()
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\FinanceDataReader\krx\listing.py in read(self)
#      23
#      24         url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13'
# ---> 25         df_listing = pd.read_html(url, header=0)[0]
#      26         cols_ren = {'회사명':'Name', '종목코드':'Symbol', '업종':'Sector', '주요제품':'Industry',
#      27                             '상장일':'ListingDate', '결산월':'SettleMonth',  '대표자명':'Representative',
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py in _build_doc(self)
#     743                     pass
#     744             else:
# --> 745                 raise e
#     746         else:
#     747             if not hasattr(r, "text_content"):
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py in _build_doc(self)
#     724         try:
#     725             if is_url(self.io):
# --> 726                 with urlopen(self.io) as f:
#     727                     r = parse(f, parser=parser)
#     728             else:
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     209     import urllib.request
#     210
# --> 211     return urllib.request.urlopen(*args, **kwargs)
#     212
#     213
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\urllib\request.py in http_open(self, req)
#    1373
#    1374     def http_open(self, req):
# -> 1375         return self.do_open(http.client.HTTPConnection, req)
#    1376
#    1377     http_request = AbstractHTTPHandler.do_request_
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             except OSError as err: # timeout error
#    1349                 raise URLError(err)
# -> 1350             r = h.getresponse()
#    1351         except:
#    1352             h.close()
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\http\client.py in getresponse(self)
#    1347         try:
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#    1351                 self.close()
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\http\client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\http\client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다

# %%
# 앞 쪽 기본 정보
stocks_kospi.head()
# Out:
#    Symbol Market               Name           Sector             Industry  \
# 1  095570  KOSPI             AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2  006840  KOSPI              AK홀딩스           기타 금융업                 지주사업
# 6  152100  KOSPI        ARIRANG 200              NaN                  NaN
# 7  295820  KOSPI    ARIRANG 200동일가중              NaN                  NaN
# 8  253150  KOSPI  ARIRANG 200선물레버리지              NaN                  NaN
#
#   ListingDate SettleMonth     Representative                       HomePage  \
# 1  2015-08-21         12월           박대현, 손삼달         http://www.ajnet.co.kr
# 2  1999-08-11         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr
# 6         NaT         NaN                NaN                            NaN
# 7         NaT         NaN                NaN                            NaN
# 8         NaT         NaN                NaN                            NaN
#
#   Region
# 1  서울특별시
# 2  서울특별시
# 6    NaN
# 7    NaN
# 8    NaN

# %%
# 앞 쪽 특정 갯수 정보 보기
stocks_kospi.head(10)
# Out:
#     Symbol Market                Name           Sector             Industry  \
# 1   095570  KOSPI              AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2   006840  KOSPI               AK홀딩스           기타 금융업                 지주사업
# 6   152100  KOSPI         ARIRANG 200              NaN                  NaN
# 7   295820  KOSPI     ARIRANG 200동일가중              NaN                  NaN
# 8   253150  KOSPI   ARIRANG 200선물레버리지              NaN                  NaN
# 9   253160  KOSPI  ARIRANG 200선물인버스2X              NaN                  NaN
# 10  395750  KOSPI   ARIRANG ESG가치주액티브              NaN                  NaN
# 11  395760  KOSPI   ARIRANG ESG성장주액티브              NaN                  NaN
# 12  278420  KOSPI     ARIRANG ESG우수기업              NaN                  NaN
# 13  429740  KOSPI      ARIRANG Fn K리츠              NaN                  NaN
#
#    ListingDate SettleMonth     Representative                       HomePage  \
# 1   2015-08-21         12월           박대현, 손삼달         http://www.ajnet.co.kr
# 2   1999-08-11         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr
# 6          NaT         NaN                NaN                            NaN
# 7          NaT         NaN                NaN                            NaN
# 8          NaT         NaN                NaN                            NaN
# 9          NaT         NaN                NaN                            NaN
# 10         NaT         NaN                NaN                            NaN
# 11         NaT         NaN                NaN                            NaN
# 12         NaT         NaN                NaN                            NaN
# 13         NaT         NaN                NaN                            NaN
#
#    Region
# 1   서울특별시
# 2   서울특별시
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN

# %%
# 뒷 쪽 특정 갯수 정보 보기
stocks_kospi.tail(10)
# Out:
#       Symbol Market              Name  Sector        Industry ListingDate  \
# 8021  000540  KOSPI              흥국화재     보험업            손해보험  1974-12-05
# 8022  000547  KOSPI           흥국화재2우B     NaN             NaN         NaT
# 8023  000545  KOSPI             흥국화재우     NaN             NaN         NaT
# 8024  003280  KOSPI              흥아해운  해상 운송업  외항화물운송업(케미컬탱커)  1976-06-29
# 8026  435530  KOSPI   히어로즈 TDF2030액티브     NaN             NaN         NaT
# 8027  435540  KOSPI   히어로즈 TDF2040액티브     NaN             NaN         NaT
# 8028  435550  KOSPI   히어로즈 TDF2050액티브     NaN             NaN         NaT
# 8029  437550  KOSPI  히어로즈 글로벌리츠이지스액티브     NaN             NaN         NaT
# 8030  419890  KOSPI   히어로즈 단기채권ESG액티브     NaN             NaN         NaT
# 8031  429870  KOSPI     히어로즈 리츠이지스액티브     NaN             NaN         NaT
#
#      SettleMonth Representative                    HomePage Region
# 8021         12월            임규준  http://www.insurance.co.kr  서울특별시
# 8022         NaN            NaN                         NaN    NaN
# 8023         NaN            NaN                         NaN    NaN
# 8024         12월            이환구      http://www.heung-a.com  서울특별시
# 8026         NaN            NaN                         NaN    NaN
# 8027         NaN            NaN                         NaN    NaN
# 8028         NaN            NaN                         NaN    NaN
# 8029         NaN            NaN                         NaN    NaN
# 8030         NaN            NaN                         NaN    NaN
# 8031         NaN            NaN                         NaN    NaN

# %% [markdown]
# #### 불러온 자료 저장하기

# %%
# 1. CSV(Comma Separated Value) : CSV 파일 포맷은 데이터 값이 쉽표(comma)로 구분되는 텍스트 파일
import pandas as pd
stocks_kospi.to_csv("krx.csv")

# %%
# 2. 엑셀로 저장하기

import pandas as pd
stocks_kospi.to_excel("krx.xlsx")

# %%
# 기타 저장방법
# pickle로 저장
# to_pickle("krx.pkl")
# db로 저장하기도 가능

# %% [markdown]
# #### pandas 활용 : 저장된 자료 다시 불러오기

# %%
# 파이썬 pandas 활용하면 저장된 데이터를 불러와서 DataFrame에 저장하게 됨.
# read 다음에 파일 형식에 따라 언더바"_"  이거나 마침표"."를 하고 괄호()안에 파일명 기입 (경로)
# read_csv() , read_excel()  ,  read_html()  등
# 엑셀 파일은 csv 로 저장 가능.

# pd.read_excel('경로/파일명.xlsx')     #파일이 xlsx(엑셀)일 경우   
# pd.read_csv('경로/파일명.csv')       #파일이 csv일 경우

import pandas as pd
pd.read_csv("krx.csv")
# Out:
#       Unnamed: 0  Symbol Market               Name           Sector  \
# 0              1  095570  KOSPI             AJ네트웍스  산업용 기계 및 장비 임대업
# 1              2  006840  KOSPI              AK홀딩스           기타 금융업
# 2              6  152100  KOSPI        ARIRANG 200              NaN
# 3              7  295820  KOSPI    ARIRANG 200동일가중              NaN
# 4              8  253150  KOSPI  ARIRANG 200선물레버리지              NaN
# ...          ...     ...    ...                ...              ...
# 6304        8027  435540  KOSPI    히어로즈 TDF2040액티브              NaN
# 6305        8028  435550  KOSPI    히어로즈 TDF2050액티브              NaN
# 6306        8029  437550  KOSPI   히어로즈 글로벌리츠이지스액티브              NaN
# 6307        8030  419890  KOSPI    히어로즈 단기채권ESG액티브              NaN
# 6308        8031  429870  KOSPI      히어로즈 리츠이지스액티브              NaN
#
#                  Industry ListingDate SettleMonth     Representative  \
# 0     렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월           박대현, 손삼달
# 1                    지주사업  1999-08-11         12월  채형석, 이석주(각자 대표이사)
# 2                     NaN         NaN         NaN                NaN
# 3                     NaN         NaN         NaN                NaN
# 4                     NaN         NaN         NaN                NaN
# ...                   ...         ...         ...                ...
# 6304                  NaN         NaN         NaN                NaN
# 6305                  NaN         NaN         NaN                NaN
# 6306                  NaN         NaN         NaN                NaN
# 6307                  NaN         NaN         NaN                NaN
# 6308                  NaN         NaN         NaN                NaN
#
#                            HomePage Region
# 0            http://www.ajnet.co.kr  서울특별시
# 1     http://www.aekyunggroup.co.kr  서울특별시
# 2                               NaN    NaN
# 3                               NaN    NaN
# 4                               NaN    NaN
# ...                             ...    ...
# 6304                            NaN    NaN
# 6305                            NaN    NaN
# 6306                            NaN    NaN
# 6307                            NaN    NaN
# 6308                            NaN    NaN
#
# [6309 rows x 11 columns]

# %%
pd.read_csv("krx.csv", index_col='Name')
# Out:
#                    Symbol Market           Sector             Industry  \
# Name
# AJ네트웍스             095570  KOSPI  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# AK홀딩스              006840  KOSPI           기타 금융업                 지주사업
# ARIRANG 200        152100  KOSPI              NaN                  NaN
# ARIRANG 200동일가중    295820  KOSPI              NaN                  NaN
# ARIRANG 200선물레버리지  253150  KOSPI              NaN                  NaN
# ...                   ...    ...              ...                  ...
# 히어로즈 TDF2040액티브    435540  KOSPI              NaN                  NaN
# 히어로즈 TDF2050액티브    435550  KOSPI              NaN                  NaN
# 히어로즈 글로벌리츠이지스액티브   437550  KOSPI              NaN                  NaN
# 히어로즈 단기채권ESG액티브    419890  KOSPI              NaN                  NaN
# 히어로즈 리츠이지스액티브      429870  KOSPI              NaN                  NaN
#
#                   ListingDate SettleMonth     Representative  \
# Name
# AJ네트웍스             2015-08-21         12월           박대현, 손삼달
# AK홀딩스              1999-08-11         12월  채형석, 이석주(각자 대표이사)
# ARIRANG 200               NaN         NaN                NaN
# ARIRANG 200동일가중           NaN         NaN                NaN
# ARIRANG 200선물레버리지         NaN         NaN                NaN
# ...                       ...         ...                ...
# 히어로즈 TDF2040액티브           NaN         NaN                NaN
# 히어로즈 TDF2050액티브           NaN         NaN                NaN
# 히어로즈 글로벌리츠이지스액티브          NaN         NaN                NaN
# 히어로즈 단기채권ESG액티브           NaN         NaN                NaN
# 히어로즈 리츠이지스액티브             NaN         NaN                NaN
#
#                                         HomePage Region
# Name
# AJ네트웍스                    http://www.ajnet.co.kr  서울특별시
# AK홀딩스              http://www.aekyunggroup.co.kr  서울특별시
# ARIRANG 200                                  NaN    NaN
# ARIRANG 200동일가중                              NaN    NaN
# ARIRANG 200선물레버리지                            NaN    NaN
# ...                                          ...    ...
# 히어로즈 TDF2040액티브                              NaN    NaN
# 히어로즈 TDF2050액티브                              NaN    NaN
# 히어로즈 글로벌리츠이지스액티브                             NaN    NaN
# 히어로즈 단기채권ESG액티브                              NaN    NaN
# 히어로즈 리츠이지스액티브                                NaN    NaN
#
# [6309 rows x 9 columns]

# %% [markdown]
# #####  경로 저장된 자료 불러오기

# %%
#파일 경로 찾는 법 : 불러올 파일을 마우스 우클릭 --> 속성 --> 위치에서 경로 확인
# C:\Users\user\Desktop  --> \ 를 /로 바꿔주기 
# C:/Users/user/Desktop  *(/를 인식할 떄도 있고 \를 인식 할 때도 있는 것 같다 되는 걸 쓰자)

# encoding = 'utf-8'
# 글자를 읽어 올 떄 utf-8의 약속대로 읽어오라는 의미
# 왠만하면 이걸로 꺠진 글씨들을 읽어 올 수 있다.


# encoding = '인코딩 방식'
# 글자를 읽어 올때 어떠한 방식으로 익어 올 것인지 지정하는 것
# 대부분 encoding = utf-8 을 기입하면 된다.

# data = pd.read_csv('파일경로 or url', sep='\t', engine = 'python', encoding = 'utf-8')

# data = pd.read_csv('파일경로 or url', sep =',' , encoding = '인코딩 방식')

# %%
pd.read_csv("C:/finance_data/titanic.csv", engine = 'python', encoding = 'utf-8')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.read_excel("C:/finance_data.titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17552/2961278357.py in <module>
# ----> 1 pd.read_excel("C:/finance_data.titanic.csv")
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     708         else:
#     709             # Binary mode
# --> 710             handle = open(handle, ioargs.mode)
#     711         handles.append(handle)
#     712
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/finance_data.titanic.csv'

# %%
# 해외시장 데이터 가져오기
# : 'NASDAQ', 'NYSE', 'AMEX' and 'S&P500', 'SSE'(상해), 'SZSE'(심천), 'HKEX'(홍콩), 'TSE'(도쿄)

# %%
# KRX delistings: 'KRX-DELISTING'(상장폐지종목), 'KRX-ADMINISTRATIVE' (관리종목)
# ETF Symbol listings(for multiple countries): 'KR', 'US', 'JP'

# %%
# 개별종목 주가 가져오기
import FinanceDataReader as fdr

# 삼성전자(005930) 전체 (1996-11-05 ~ 현재)
df = fdr.DataReader('005930')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1998-08-03    837    850    821    823    243930       NaN
# 1998-08-04    813    847    810    838    275470  0.018226
# 1998-08-05    837    843    791    806    422420 -0.038186
# 1998-08-06    787    822    785    806    272430  0.000000
# 1998-08-07    809    841    809    832    392600  0.032258
# ...           ...    ...    ...    ...       ...       ...
# 2022-10-20  55200  56000  55100  55500  17107653 -0.005376
# 2022-10-21  55100  56300  55100  55900  11456060  0.007207
# 2022-10-24  57000  57500  56700  57500  16944503  0.028623
# 2022-10-25  57000  58600  57000  57700  17405678  0.003478
# 2022-10-26  58000  59500  57700  59400  13884764  0.029463
#
# [6000 rows x 6 columns]

# %%
df.head()
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 1998-07-14   856   863   843    862  186170       NaN
# 1998-07-15   867   883   860    862  416460  0.000000
# 1998-07-16   893   964   871    964  750770  0.118329
# 1998-07-18   983  1070   977   1013  727400  0.050830
# 1998-07-20  1042  1133  1025   1134  892800  0.119447

# %%
df.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-09-26  53700  54200  53600  53900  15008449 -0.011009
# 2022-09-27  53800  54200  53500  54200  16631289  0.005566
# 2022-09-28  53900  54400  52500  52900  19991129 -0.023985
# 2022-09-29  53300  53700  52600  52600  13882080 -0.005671
# 2022-09-30  52300  53500  51800  53300  14075717  0.013308

# %%
df.tail(10)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-09-19  56300  57000  56000  56400  12278653  0.003559
# 2022-09-20  56400  57000  55800  55800  14041465 -0.010638
# 2022-09-21  55400  55500  55000  55300  11863700 -0.008961
# 2022-09-22  54600  54700  54300  54400  12786510 -0.016275
# 2022-09-23  54400  54900  54200  54500  10555964  0.001838
# 2022-09-26  53700  54200  53600  53900  15008449 -0.011009
# 2022-09-27  53800  54200  53500  54200  16631289  0.005566
# 2022-09-28  53900  54400  52500  52900  19991129 -0.023985
# 2022-09-29  53300  53700  52600  52600  13882080 -0.005671
# 2022-09-30  52300  53500  51800  53300  14075717  0.013308

# %%
# 특정 기간에 이후 부터 현재까지 개별 종목 주가 가져오기
# Date 주식시장 날짜
# Open  시가# High 고가# Low 저가# Close 종가
# Volume 해당 개장일의 거래량
# Change는 해당 개장일의 전날 대비 종가 상승률 
import FinanceDataReader as fdr
fdr.DataReader('005930', start = '2020' ).reset_index()
# Out:
#           Date   Open   High    Low  Close    Volume    Change
# 0   2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 1   2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2   2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 3   2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 4   2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ..         ...    ...    ...    ...    ...       ...       ...
# 675 2022-09-26  53700  54200  53600  53900  15008449 -0.011009
# 676 2022-09-27  53800  54200  53500  54200  16631289  0.005566
# 677 2022-09-28  53900  54400  52500  52900  19991129 -0.023985
# 678 2022-09-29  53300  53700  52600  52600  13882080 -0.005671
# 679 2022-09-30  52300  53600  51800  53100  21823113  0.009506
#
# [680 rows x 7 columns]

# %%
# 특정 기간에 대하여 개별 종목 주가 가져오기
start_date = '2022-01-03'
end_date = '2022-10-25'
df_fdr = fdr.DataReader('005930', start=start_date, end=end_date)
df_fdr
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-10-19  56700  56900  55700  55800  12660652 -0.012389
# 2022-10-20  55200  56000  55100  55500  17107653 -0.005376
# 2022-10-21  55100  56300  55100  55900  11456060  0.007207
# 2022-10-24  57000  57500  56700  57500  16944503  0.028623
# 2022-10-25  57000  58600  57000  57700  17405678  0.003478
#
# [199 rows x 6 columns]

# %% [markdown]
# #### 시각화

# %%
# 그래픽 종류
# line	line graph
# pie	pie chart
# scatter	scatter plot
# bar, barh	vertical, horizontal bar charts
# area	area plots
# box	box plot
# hexbin	hexbin plot
# hist	histogram
# kde, density	kernel density charts

# %%
# 라인 그래프로 보여주기
df = fdr.DataReader('005930', '2020')
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 막대그래프 보여주기
df['Close'].hist()
# Out:
# <AxesSubplot:>

# %%
#2021 주가 가져오기
import FinanceDataReader as fdr
fdr.DataReader('005930', start = '2021', end = '2021')
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []

# %%
#2021 주가 가져오기
import FinanceDataReader as fdr
fdr.DataReader('005930', start = '2021', end = '2022')
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2021-12-24  80200  80800  80200  80500  12086380  0.007509
# 2021-12-27  80600  80600  79800  80200  10783368 -0.003727
# 2021-12-28  80200  80400  79700  80300  18226325  0.001247
# 2021-12-29  80200  80200  78500  78800  19794795 -0.018680
# 2021-12-30  78900  79500  78100  78300  14236700 -0.006345
#
# [248 rows x 6 columns]

# %% [markdown]
# ###  2. pandas_datareader

# %% [markdown]
# ### 네이버에서,  yahoo

# %%
# 데이터소스 :  naver로 지정하면 1990년 데이터부터 조회할 수 있고, yahoo로 지정하면 2000년 데이터부터 조회 가능
# 액면분할이 고려된 수정주가로 조회됨
# yahoo finance를 데이터소스로 사용할 때는 종목코드 뒤에 코스피 종목인 경우 .KS, 코스닥 종목인 경우 .KQ를 붙여줘야 함

# %%
# 설치하기
pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas-datareader) (2.26.0)
# Requirement already satisfied: lxml in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas-datareader) (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)

# %%
import pandas_datareader.data as pdr
df_pdr = pdr.DataReader('005930', 'naver', start=start_date, end=end_date)
df_pdr
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-01-03  79400  79800  78200  78600  13502112
# 2022-01-04  78800  79200  78300  78700  12427416
# 2022-01-05  78800  79000  76400  77400  25470640
# 2022-01-06  76700  77600  76600  76900  12931954
# 2022-01-07  78100  78400  77400  78300  15163757
# ...           ...    ...    ...    ...       ...
# 2022-09-19  56300  57000  56000  56400  12278653
# 2022-09-20  56400  57000  55800  55800  14041465
# 2022-09-21  55400  55500  55000  55300  11863700
# 2022-09-22  54600  54700  54300  54400  12786510
# 2022-09-23  54400  54900  54200  54500  10555964
#
# [179 rows x 5 columns]

# %%
import pandas_datareader.data as web

df = web.DataReader('005930', 'naver', start='2022-01-01', end='2022-05-30')

df
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-01-03  79400  79800  78200  78600  13502112
# 2022-01-04  78800  79200  78300  78700  12427416
# 2022-01-05  78800  79000  76400  77400  25470640
# 2022-01-06  76700  77600  76600  76900  12931954
# 2022-01-07  78100  78400  77400  78300  15163757
# ...           ...    ...    ...    ...       ...
# 2022-05-24  67500  67700  66500  66500  15482576
# 2022-05-25  66700  67100  65900  66400  15150490
# 2022-05-26  66300  67200  65500  65900  15970890
# 2022-05-27  66700  66900  66200  66500  11405555
# 2022-05-30  67500  67800  66900  67700  14255484
#
# [100 rows x 5 columns]

# %%
# yahoo finance를 데이터 소스로 사용할 때는 종목코드 뒤에 코스피 종목인 경우 .KS, 코스닥 종목인 경우 .KQ를 붙여줘야 함
df_pdr = pdr.DataReader('005930.KS', 'yahoo', start=start_date, end=end_date)
df_pdr
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2022-01-04  79200.0  78300.0  78800.0  78700.0  12427416.0  77819.453125
# 2022-01-05  79000.0  76400.0  78800.0  77400.0  25470640.0  76534.000000
# 2022-01-06  77600.0  76600.0  76700.0  76900.0  12931954.0  76039.593750
# 2022-01-07  78400.0  77400.0  78100.0  78300.0  15163757.0  77423.921875
# 2022-01-10  78100.0  77100.0  78100.0  78000.0   9947422.0  77127.289062
# ...             ...      ...      ...      ...         ...           ...
# 2022-09-19  57000.0  56000.0  56300.0  56400.0  12278653.0  56400.000000
# 2022-09-20  57000.0  55800.0  56400.0  55800.0  14041465.0  55800.000000
# 2022-09-21  55500.0  55000.0  55400.0  55300.0  11863700.0  55300.000000
# 2022-09-22  54700.0  54300.0  54600.0  54400.0  12786510.0  54400.000000
# 2022-09-23  54900.0  54200.0  54400.0  54500.0  10555964.0  54500.000000
#
# [177 rows x 6 columns]

# %%
# # DataReader API를 통해서 yahoo finance의 주식 종목 데이터를 가져온다.

# %%
df = pdr.DataReader('AAPL', 'yahoo')

# %%
# 애플 주가가져오기
# df = pdr.get_data_yahoo('주식 종목코드') 

df = pdr.get_data_yahoo('AAPL')
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-10-02   38.612499   38.180000   38.564999   38.452499   74795200.0
# 2017-10-03   38.772499   38.477501   38.502499   38.619999   64921200.0
# 2017-10-04   38.465000   38.115002   38.407501   38.369999   80655200.0
# 2017-10-05   38.860001   38.512501   38.544998   38.847500   85135200.0
# 2017-10-06   38.872501   38.639999   38.742500   38.825001   69630400.0
# ...                ...         ...         ...         ...          ...
# 2022-09-23  151.470001  148.559998  151.190002  150.429993   95939200.0
# 2022-09-26  153.770004  149.639999  149.660004  150.770004   93339400.0
# 2022-09-27  154.720001  149.949997  152.740005  151.759995   84442700.0
# 2022-09-28  150.639999  144.839996  147.639999  149.839996  146691400.0
# 2022-09-29  146.720001  140.679993  146.100006  142.479996  127977800.0
#
#              Adj Close
# Date
# 2017-10-02   36.493938
# 2017-10-03   36.652901
# 2017-10-04   36.415638
# 2017-10-05   36.868816
# 2017-10-06   36.847458
# ...                ...
# 2022-09-23  150.429993
# 2022-09-26  150.770004
# 2022-09-27  151.759995
# 2022-09-28  149.839996
# 2022-09-29  142.479996
#
# [1258 rows x 6 columns]

# %%
# # 선택적으로 일정 기간동안의 주식 정보를 가져오는 방법
# from datetime import datetime start = datetime(2018,1,1)end = datetime(2019,12,31) 
# df = pdr.DataReader('주식 종목코드', 'yahoo', start, end)
# df = pdr.get_data_yahoo('주식 종목코드', start, end)

# %%
from datetime import datetime 
start = datetime(2022,1,1)
end = datetime(2022,7,30) 
df = pdr.DataReader('AAPL', 'yahoo', start, end)
df = pdr.get_data_yahoo('AAPL', start, end)

# %% [markdown]
# ### 3. pykrx

# %%
# https://github.com/sharebook-kr/pykrx

# KRX, Naver 등의 웹사이트에서 주가정보를 스크래핑하는 모듈

# 특정 시점의 상장 종목코드 조회 가능
# 해당 종목코드의 종목명을 조회하는 함수가 별도로 존재

# %%
# 설치하기
# !pip install pykrx
# Out:
# 파일 C:\Users\JYB\AppData\Local\Microsoft\WindowsApps\pip.exe을(를) 찾을 수 없습니다.

# %%
# pykrx의 stock 모듈을 import 한 후 다른 작업 진행

# %%
# "get_market_ticker_list" 메서드는 주식 종목들을 가져오기
# "get_market_ticker_name" 메서드는 심볼(티커)을 받으면 기업 이름을 가져오기

# %%
# KOSPI/KOSDAQ/KONEX 종목코드 조회
from pykrx import stock

stock_code = stock.get_market_ticker_list(date="20220630", market="ALL")
(stock_code[:6], len(stock_code))
# Out:
# (['060310', '095570', '006840', '054620', '265520', '211270'], 2629)

# %%
# KOSPI 종목코드 조회
stock_code = stock.get_market_ticker_list(date="20220928", market="KOSPI")
(stock_code[:6], len(stock_code))
# Out:
# (['095570', '006840', '027410', '282330', '138930', '001460'], 939)

# %%
kospi = stock.get_market_ticker_list("20220617", market="KOSPI")
kospi[:5]
# Out:
# ['095570', '006840', '027410', '282330', '138930']

# %%
# KOSDAQ 종목코드 조회
stock_code = stock.get_market_ticker_list(date="20220928", market="KOSDAQ")
(stock_code[:6], len(stock_code))
# Out:
# (['060310', '054620', '265520', '211270', '032790', '013720'], 1582)

# %%
# 종목명 반환
stock_name = stock.get_market_ticker_name("005930")
stock_name
# Out:
# '삼성전자'

# %%
# "get_market_ohlcv" 메서드는 OHLCV 주식 시세를 가져오기
# 일자별 OHLCV(시가, 고가, 저가, 종가, 거래량) 조회¶

# 삼성전자의 20220101~20220920의 주가데이터
df = stock.get_market_ohlcv_by_date(fromdate="20220101", todate="20220920", ticker="005930")
df
# Out:
#                시가     고가     저가     종가       거래량
# 날짜
# 2022-01-03  79400  79800  78200  78600  13502112
# 2022-01-04  78800  79200  78300  78700  12427416
# 2022-01-05  78800  79000  76400  77400  25470640
# 2022-01-06  76700  77600  76600  76900  12931954
# 2022-01-07  78100  78400  77400  78300  15163757
# ...           ...    ...    ...    ...       ...
# 2022-09-14  56200  57200  56100  56800  12524961
# 2022-09-15  57000  57100  56000  56000  11664819
# 2022-09-16  55600  56400  55500  56200  13456503
# 2022-09-19  56300  57000  56000  56400  12278653
# 2022-09-20  56400  57000  55800  55800  14041465
#
# [176 rows x 5 columns]

# %%
# 일정 기간 종목의 가격 변동 조회Permalink
# get_market_price_change_by_ticker(fromdate=”조회시작일”, todate=”조회종료일”, market=”거래소명”)

# %%
df = stock.get_market_price_change_by_ticker(fromdate="20220801", todate="20220920")
df.head()
# Out:
#             종목명      시가      종가    변동폭    등락률       거래량          거래대금
# 티커
# 095570   AJ네트웍스    8030    7830   -200 -249.0   5463509   43102591480
# 006840    AK홀딩스   16350   15750   -600 -367.0    344494    5587561800
# 027410      BGF    4215    3900   -315 -747.0   4444087   18277872435
# 282330   BGF리테일  181000  164000 -17000 -939.0   1947992  322270114000
# 138930  BNK금융지주    6790    6610   -180 -265.0  34970261  234444930075

# %%
# 특정 일자 전체 종목 시세 OHLCV(시가, 고가, 저가, 종가, 거래량, 거래대금, 등락률) 가져오기
# stock.get_market_ohlcv_by_ticker(date=날짜)

# %%
df = stock.get_market_ohlcv_by_ticker(date="20220920")
df.head()
# Out:
#             시가      고가      저가      종가      거래량         거래대금   등락률
# 티커
# 095570    7980    8140    7830    7830   214050   1707067150  0.64
# 006840   15300   15800   15300   15750     7227    112495150  1.29
# 027410    3845    3925    3805    3900   119734    466020190  1.43
# 282330  166000  168000  162500  164000    73238  12111634000 -0.30
# 138930    6580    6660    6550    6610  1139966   7534064600  0.76

# %%
# 개별종목 날짜별 OHLCV(시가, 고가, 저가, 종가, 거래량, 거래대금, 등락률) 가져오기
# stock.get_market_ohlcv_by_date(조회시작일, 조회종료일, 종목코드)

# %%
df = stock.get_market_ohlcv_by_date("20220820", "20220925", "005930")
df.head()
# Out:
#                시가     고가     저가     종가      거래량
# 날짜
# 2022-08-22  60300  60400  59800  60000  8259865
# 2022-08-23  59000  59600  59000  59100  9041629
# 2022-08-24  59200  59500  59000  59000  8888486
# 2022-08-25  59200  59700  59000  59700  5767902
# 2022-08-26  60300  60900  59900  60000  9499995

# %%
df = stock.get_market_ohlcv_by_date("20220820", "20220925", "005930")
df
# Out:
#                시가     고가     저가     종가       거래량
# 날짜
# 2022-08-22  60300  60400  59800  60000   8259865
# 2022-08-23  59000  59600  59000  59100   9041629
# 2022-08-24  59200  59500  59000  59000   8888486
# 2022-08-25  59200  59700  59000  59700   5767902
# 2022-08-26  60300  60900  59900  60000   9499995
# 2022-08-29  58700  58900  58600  58600   9841329
# 2022-08-30  58700  59000  58300  58800   9690044
# 2022-08-31  58200  59900  58200  59700  14203512
# 2022-09-01  58700  58900  58300  58400  14905777
# 2022-09-02  58300  58600  57500  57500  15040310
# 2022-09-05  57400  57800  56800  57100  11425977
# 2022-09-06  57200  57600  56900  57100   7503086
# 2022-09-07  56700  56700  55900  56000  17384854
# 2022-09-08  56200  56400  55600  55600  18000016
# 2022-09-13  57000  58500  56800  58100  17166581
# 2022-09-14  56200  57200  56100  56800  12524961
# 2022-09-15  57000  57100  56000  56000  11664819
# 2022-09-16  55600  56400  55500  56200  13456503
# 2022-09-19  56300  57000  56000  56400  12278653
# 2022-09-20  56400  57000  55800  55800  14041465
# 2022-09-21  55400  55500  55000  55300  11863700
# 2022-09-22  54600  54700  54300  54400  12786510
# 2022-09-23  54400  54900  54200  54500  10555964

# %%
# 전체 종목의 펀더멘탈 지표(PER, PBR, EPS, BPS, DIV, DPS) 가져오기
# stock.get_market_fundamental_by_ticker(date=날짜, market=거래소)

# market의 기본값은 "ALL"

# DIV(배당수익률): (주가배당금/주가) * 100

# BPS(주당순자산가치=청산가치): (순자산)/(총발행주식수)

# PER(주가수익비율): (주가)/(주당순이익)

# EPS(주당순이익): (당기순이익)/(총발행주식수)

# PBR(주가순자산비율) = (주가)/(BPS) = PER*EPS / BPS

# %%
df = stock.get_market_fundamental_by_ticker(date='20220617', market="ALL")
df.head()
# Out:
#           BPS         PER       PBR   EPS       DIV  DPS
# 티커
# 060310    792  174.750000  3.529297    16  0.000000    0
# 095570   8075    3.949219  0.839844  1707  4.000000  270
# 006840  45961    0.000000  0.370117     0  1.169922  200
# 054620  10088    8.070312  0.939941  1179  1.049805  100
# 265520  12713    4.878906  1.509766  3932  1.250000  240

# %%
# 특정일자의 종목별 DIV/BPS/PER/EPS 조회
# get_market_fundamental_by_ticker (date="YYYYMMDD", market="거래소명")

# %%
df = stock.get_market_fundamental_by_ticker(date="20210520")
df.head()
# Out:
#           BPS        PER       PBR   EPS       DIV   DPS
# 티커
# 095570   6089   0.000000  0.959961     0  3.609375   210
# 006840  50471   0.000000  0.689941     0  1.139648   400
# 027410  15781  23.937500  0.429932   285  1.610352   110
# 282330  40317  25.062500  4.421875  7103  1.349609  2400
# 138930  26781   5.308594  0.300049  1498  4.019531   320

# %%
# 일자별 개별종목 DIV/BPS/PER/EPS 조회
# get_market_fundamental_by_date(fromdate, todate, ticker, freq='d', name_display=False)

# freq: d(일), m(월), y(연도)

# %%
df = stock.get_market_fundamental_by_date(fromdate="20200101", todate="20211231", ticker="005930")
df
# Out:
#               BPS    PER   PBR   EPS   DIV   DPS
# 날짜
# 2020-01-02  35342   8.54  1.56  6461  2.57  1416
# 2020-01-03  35342   8.59  1.57  6461  2.55  1416
# 2020-01-06  35342   8.59  1.57  6461  2.55  1416
# 2020-01-07  35342   8.64  1.58  6461  2.54  1416
# 2020-01-08  35342   8.79  1.61  6461  2.49  1416
# ...           ...    ...   ...   ...   ...   ...
# 2021-12-24  39406  20.96  2.04  3841  3.72  2994
# 2021-12-27  39406  20.88  2.04  3841  3.73  2994
# 2021-12-28  39406  20.91  2.04  3841  3.73  2994
# 2021-12-29  39406  20.52  2.00  3841  3.80  2994
# 2021-12-30  39406  20.39  1.99  3841  3.82  2994
#
# [496 rows x 6 columns]

# %%
#frequency 파라미터(d/m/y)를 추가
df = stock.get_market_fundamental_by_date("20200101", "20200430", "005930", freq="m")
print(df.head(2))
# Out:
#               BPS   PER   PBR   EPS   DIV   DPS
# 날짜
# 2020-01-31  35342  8.54  1.56  6461  2.57  1416
# 2020-02-29  35342  8.85  1.62  6461  2.48  1416

# %%
df = stock.get_market_fundamental_by_date(fromdate="20200101", todate="20211231", ticker="005930")
df.head()
# Out:
#               BPS   PER   PBR   EPS   DIV   DPS
# 날짜
# 2020-01-02  35342  8.54  1.56  6461  2.57  1416
# 2020-01-03  35342  8.59  1.57  6461  2.55  1416
# 2020-01-06  35342  8.59  1.57  6461  2.55  1416
# 2020-01-07  35342  8.64  1.58  6461  2.54  1416
# 2020-01-08  35342  8.79  1.61  6461  2.49  1416

# %%
df = stock.get_market_ohlcv("20150720", "20150810", "005930")
print(df.head(3))

# %%
#지정된 기간 동안의 일자별로 정렬된 (순매수) 거래량
df = stock.get_market_trading_value_by_date("20210101", "20210701", "005930")
print(df.head())
# Out:
#                     기관합계         기타법인             개인         외국인합계  전체
# 날짜
# 2021-01-04 -326136950200  48480486000   658901836000 -381245371800   0
# 2021-01-05 -203963791100   7236010900   622727193300 -425999413100   0
# 2021-01-06 -442463559600  13521042200  1013153304900 -584210787500   0
# 2021-01-07  250129976600  17802746700   -71008181500 -196924541800   0
# 2021-01-08 -436089196200   1958064400  -169881010800  604012142600   0

# %%
# 매수 혹은 매도 금액을 조회하고 싶다면 on 파라미터에 입력할 수 있습니다. 입력하지 않는다면 순매수 금액이 조회
df = stock.get_market_trading_value_by_date("20210115", "20210122", "005930", on='매도')
print(df.head())
# Out:
#                      기관합계         기타법인             개인         외국인합계  \
# 날짜
# 2021-01-15  1505250243300  19525756900   925426195700  525029741764
# 2021-01-18  1353223733500  22132983500  1883422627200  456996648400
# 2021-01-19  1205081446400  28155090000  1800734616800  407371601300
# 2021-01-20  1147190346800  10015618200   643413644500  405119540200
# 2021-01-21   878411497500  41184362100   851899126900  439714802000
#
#                        전체
# 날짜
# 2021-01-15  2975231937664
# 2021-01-18  3715775992600
# 2021-01-19  3441342754500
# 2021-01-20  2205739149700
# 2021-01-21  2211209788500

# %%
df = stock.get_market_trading_value_by_date("20210115", "20210122", "005930", on='매수')
print(df.head())
# Out:
#                      기관합계         기타법인             개인         외국인합계  \
# 날짜
# 2021-01-15  1064481034000  44968044700  1587035281300  278747577664
# 2021-01-18  1395547268500  44815328300  1898251748900  377161646900
# 2021-01-19  1300604499900  24904667500  1627250403500  488583183600
# 2021-01-20   782714132800  32996251100  1073529225500  316499540300
# 2021-01-21   817773991200  13303508100  1102184636900  277947652300
#
#                        전체
# 날짜
# 2021-01-15  2975231937664
# 2021-01-18  3715775992600
# 2021-01-19  3441342754500
# 2021-01-20  2205739149700
# 2021-01-21  2211209788500

# %%
# 시장의 거래대금을 조회할 때는 ETF, ETN ELW의 포함 여부를 지정할 수 있습니다. 
# 만약 값을 지정하지 않는다면 해당 데이터를 제외한 값을을 반환

df = stock.get_market_trading_value_by_date("20210115", "20210122", "KOSPI", etf=True, etn=True, elw=True)
print(df.head())
# Out:
#                      기관합계         기타법인             개인         외국인합계  전체
# 날짜
# 2021-01-15 -1536570309441  63110174617  2251672617980 -778212483156   0
# 2021-01-18  -601428111357 -27000808439   494341183227  134087736569   0
# 2021-01-19   544654406338  21787409868  -968965427363  402523611157   0
# 2021-01-20 -1227642472619  32139813590  1444113501769 -248610842740   0
# 2021-01-21  -284899892322 -19072459127   -61503500921  365475852370   0

# %%
#일자별 시장의 거래량을 조회
df = stock.get_market_trading_volume_by_date("20220101", "20220701", "005930")
print(df.head())
# Out:
#                기관합계    기타법인       개인    외국인합계  전체
# 날짜
# 2022-01-03 -4178268   60481  2349662  1768125   0
# 2022-01-04 -2623794   24292  1170907  1428595   0
# 2022-01-05 -7727282 -103764  8414591  -583545   0
# 2022-01-06 -2229379   51631   -41729  2219477   0
# 2022-01-07 -2115197  -49515 -2194573  4359285   0

# %%
# 매수 혹은 매도 거래량만을 조회하고 싶다면 on 파라미터에 입력 가능
# 입력하지 않는다면 순매수 수량이 조회
df = stock.get_market_trading_volume_by_date("20220101", "20220701", "005930", on='매도')
print(df.head())
# Out:
#                 기관합계    기타법인       개인    외국인합계        전체
# 날짜
# 2022-01-03   8759701   21053  2807663  1913695  13502112
# 2022-01-04   8463883   26174  2332823  1604536  12427416
# 2022-01-05  15538421  246850  4129142  5556227  25470640
# 2022-01-06   7164696   54432  3801704  1911122  12931954
# 2022-01-07   7090895  142380  5006070  2924412  15163757

# %%
#지정된 기간 동안의 투자자별로 정렬된 (순매수) 거래대금
df = stock.get_market_trading_value_by_investor("20210101", "20210701", "005930")
print(df.head())
# Out:
#                    매도              매수            순매수
# 투자자구분
# 금융투자   31066223912100  28464867937600 -2601355974500
# 보험      1808485504300    779839009100 -1028646495200
# 투신      3177067544700   1794360840100 -1382706704600
# 사모      1259026093300    955202197900  -303823895400
# 은행       149110410100     87504448700   -61605961400

# %%
#세 번째 파라미터에 KOSPI, KOSDAQ, KONEX를 지정하면 각 시장의 거래대금을 조회
# ALL을 입력하면 세 개의 시장을 합친 통합 거래대금을 조회
df = stock.get_market_trading_value_by_investor("20210101", "20210701", "KOSPI")
print(df.head())

# %%
#시장의 거래대금을 조회할 때는 ETF, ETN ELW의 포함 여부를 지정 가능
#만약 값을 지정하지 않는다면 해당 데이터를 제외한 값을을 반환
# 옵션은 KOSPI, KOSDAQ, KONEX 조회할 때만 유효
df = stock.get_market_trading_value_by_investor("20210115", "20210122", "KOSPI", etf=True, etn=True, elw=True)
print(df.head())
# Out:
#                    매도              매수           순매수
# 투자자구분
# 금융투자   15985568261831  15006116511544 -979451750287
# 보험      1219035502445    757575677208 -461459825237
# 투신      2235561259511   1799363743367 -436197516144
# 사모       999084910863    846067212945 -153017697918
# 은행       886226324790    936210985810   49984661020

# %%
# 지정된 기간 동안의 투자자별로 정렬된 (순매수) 거래량
df = stock.get_market_trading_volume_by_investor("20210115", "20210122", "005930")
print(df.head())
# Out:
#              매도        매수      순매수
# 투자자구분
# 금융투자   29455909  26450600 -3005309
# 보험      1757287    509535 -1247752
# 투신      2950680   1721970 -1228710
# 사모       745727    696135   -49592
# 은행        38675     46394     7719

# %%
# 종몹별 시총 가져오기
# get_market_cap_by_ticker 함수는 특정 일자의 종목별 시가총액/거래량/거래대금/상장주식수/외국인보유주식수를 조회
#외국인보유주식수는 D-2 (영업일 기준)일 까지 유효한 값이 출력되며, D-1일은 0으로 표기
df = stock.get_market_cap_by_ticker("20220901")
print(df.head())
# Out:
#             종가             시가총액       거래량          거래대금       상장주식수
# 티커
# 005930   58400  348635300920000  14905777  872374620601  5969782550
# 373220  463000  108342000000000    289808  134255218000   234000000
# 000660   92400   67267418526000   2337521  216798395700   728002365
# 207940  826000   58789724000000     51619   42488586000    71174000
# 005935   53700   44189015790000   1047819   56430850600   822886700

# %%
# 일자별 시가 총액 조회
# get_market_cap_by_date 함수는 특정 종목의 일자별 시가총액을 조회
#거래량/거래대금/상장주식수가 함께 조회
df = stock.get_market_cap_by_date("20220101", "20220701", "005930")
print(df.head())
print(df.tail())
# Out:
#                        시가총액       거래량           거래대금       상장주식수
# 날짜
# 2022-01-03  469224908430000  13502112  1066006837750  5969782550
# 2022-01-04  469821886685000  12427416   977990613000  5969782550
# 2022-01-05  462061169370000  25470640  1967841509800  5969782550
# 2022-01-06  459076278095000  12931954   996378432570  5969782550
# 2022-01-07  467433973665000  15163757  1184236552700  5969782550
#                        시가총액       거래량           거래대금       상장주식수
# 날짜
# 2022-06-27  351023213940000  18122236  1071186745402  5969782550
# 2022-06-28  354605083470000  13540538   800041009700  5969782550
# 2022-06-29  346247387900000  14677138   855770425874  5969782550
# 2022-06-30  340277605350000  18915142  1082799462452  5969782550
# 2022-07-01  335501779310000  24982097  1412473217495  5969782550

# %%
#get_market_cap_by_date() 함수에 frequency 파라미터(d/m/y)를 추가
# d는 일자, m은 월, y는 연도를 의미
# 시가총액과 상장주식수는 월별 마지막 거래일의 값을 사용
df = stock.get_market_cap_by_date("20210101", "20210701", "005930", "m")
print(df.head())
# Out:
#                        시가총액        거래량            거래대금       상장주식수
# 날짜
# 2021-01-31  489522169100000  765471247  66588164494174  5969782550
# 2021-02-28  492507060375000  432953240  36020443268993  5969782550
# 2021-03-31  485940299570000  387612356  31876803021604  5969782550
# 2021-04-30  486537277825000  372938171  31169716082524  5969782550
# 2021-05-31  480567495275000  352211074  28341778034285  5969782550

# %%
# 시가총액과 상장주식수는 월별 마지막 거래일의 값을 사용

df = stock.get_market_cap_by_date("20210101", "20210701", "005930", "m")
print(df.head())
print(df)
# Out:
#                        시가총액        거래량            거래대금       상장주식수
# 날짜
# 2021-01-31  489522169100000  765471247  66588164494174  5969782550
# 2021-02-28  492507060375000  432953240  36020443268993  5969782550
# 2021-03-31  485940299570000  387612356  31876803021604  5969782550
# 2021-04-30  486537277825000  372938171  31169716082524  5969782550
# 2021-05-31  480567495275000  352211074  28341778034285  5969782550
#                        시가총액        거래량            거래대금       상장주식수
# 날짜
# 2021-01-31  489522169100000  765471247  66588164494174  5969782550
# 2021-02-28  492507060375000  432953240  36020443268993  5969782550
# 2021-03-31  485940299570000  387612356  31876803021604  5969782550
# 2021-04-30  486537277825000  372938171  31169716082524  5969782550
# 2021-05-31  480567495275000  352211074  28341778034285  5969782550
# 2021-06-30  481761451785000  333099465  27047251878682  5969782550
# 2021-07-31  478179582255000   13382882   1073188213795  5969782550

# %%
# get_exhaustion_rates_of_foreign_investment_by_ticker 함수
#상장주식수/외국인한도수량/외국인보유수량/외국인한도소진률 정보를 조회
#외국인 보유수량 및 한도소진율은 장개시 시점 기준(금융감독원 외국인투자 관리시스템 제공 전일자 확정치)

df = stock.get_exhaustion_rates_of_foreign_investment_by_ticker('20210701')
print(df.head())
df
# Out:
#             상장주식수      보유수량        지분율       한도수량      한도소진율
# 티커
# 000020   27931470    828117   2.960938   27931470   2.960938
# 000040   96137368  44241720  46.031250   96137368  46.031250
# 000050   27415270    759750   2.769531   27415270   2.769531
# 000060  120625000  13175456  10.921875  120625000  10.921875
# 000070    8564271    742668   8.671875    8564271   8.671875
#             상장주식수      보유수량        지분율       한도수량      한도소진율
# 티커
# 000020   27931470    828117   2.960938   27931470   2.960938
# 000040   96137368  44241720  46.031250   96137368  46.031250
# 000050   27415270    759750   2.769531   27415270   2.769531
# 000060  120625000  13175456  10.921875  120625000  10.921875
# 000070    8564271    742668   8.671875    8564271   8.671875
# ...           ...       ...        ...        ...        ...
# 383220    7661415    833803  10.882812    7661415  10.882812
# 383800   76280690  11459734  15.023438   76280690  15.023438
# 38380K    1465285    138831   9.468750    1465285   9.468750
# 900140   99455297  16400685  16.484375   99455297  16.484375
# 950210   60096155  38344916  63.812500   60096155  63.812500
#
# [927 rows x 5 columns]

# %%
# 두 번째 파라미터 market은 코스피(KOSPI)/코스닥(KOSDAQ)/코넥스(KONEX) 시장을 지정해서 조회

df = stock.get_exhaustion_rates_of_foreign_investment_by_ticker('20200703', "KOSPI")
print(df.head())
# Out:
#             상장주식수      보유수량        지분율       한도수량      한도소진율
# 티커
# 000020   27931470   1400966   5.019531   27931470   5.019531
# 000040   91661018  43190959  47.125000   91661018  47.125000
# 000050   27415270    773627   2.820312   27415270   2.820312
# 000060  113680000  12968255  11.406250  113680000  11.406250
# 000070    8564271    661240   7.718750    8564271   7.718750

# %%
# 세 번째 파라미터 balance_limit을 True로 지정하면 외국인 보유한도의 제한 종목만 검색 rksmd
# 지정하지 않으면 False 

df = stock.get_exhaustion_rates_of_foreign_investment_by_ticker('20200703', "KOSPI",
balance_limit=True)
print(df.head())
# Out:
#             상장주식수       보유수량        지분율       한도수량      한도소진율
# 티커
# 003490   94844634   12350096  13.023438   47412833  26.046875
# 003495    1110794      29061   2.619141     555286   5.230469
# 015760  641964077  127919592  19.937500  256785631  49.812500
# 017670   80745711   28962369  35.875000   39565398  73.187500
# 020560  223235294   13871465   6.210938  111595323  12.429688

# %%
# get_index_name 함수를 사용해서 티커의 이름

for ticker in stock.get_index_ticker_list():
    print(ticker, stock.get_index_ticker_name(ticker))
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1022
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
# 인덱스 구성종목 조회

# 인덱스를 구성하고 있는 종목의 티커를 리스트로 반환

pdf = stock.get_index_portfolio_deposit_file("1013")
print(len(pdf), pdf)
# Out:
# 61 ['005930', '373220', '000660', '006400', '066570', '009150', '011070', '034220', '361610', '020150', '272210', '336260', '001440', '000990', '010120', '267260', '336370', '353200', '248070', '192650', '195870', '322000', '007340', '025540', '298040', '004490', '009450', '097520', '011930', '033240', '029530', '092220', '001820', '007660', '007810', '033180', '109070', '103590', '005680', '004710', '017900', '008700', '017040', '000300', '008110', '009470', '011690', '044380', '020760', '019180', '015260', '014910', '009140', '007610', '006340', '005870', '004770', '000500', '011230', '001210', '019490']

# %%
#  인덱스 OHLCV 조회
# get_index_ohlcv_by_date() 함수는 입력된 기간 동안의 인덱스 OHLCV를 조회

df = stock.get_index_ohlcv_by_date("20210601", "20210701", "1013")
print(df.head())
df
# Out:
#                   시가        고가        저가        종가        거래량           거래대금
# 날짜
# 2021-06-01  30151.15  30467.26  30005.75  30284.60  285777706  3013130482590
# 2021-06-02  30295.93  30509.45  30182.44  30249.67  212243845  3143606016255
# 2021-06-03  30247.11  31043.57  30247.11  30950.05  491314111  5299110838627
# 2021-06-04  30940.13  30940.13  30505.70  30792.65  417575114  3886262981630
# 2021-06-07  30830.22  31041.46  30636.15  30773.79  390617690  3999876683313
#                   시가        고가        저가        종가        거래량           거래대금
# 날짜
# 2021-06-01  30151.15  30467.26  30005.75  30284.60  285777706  3013130482590
# 2021-06-02  30295.93  30509.45  30182.44  30249.67  212243845  3143606016255
# 2021-06-03  30247.11  31043.57  30247.11  30950.05  491314111  5299110838627
# 2021-06-04  30940.13  30940.13  30505.70  30792.65  417575114  3886262981630
# 2021-06-07  30830.22  31041.46  30636.15  30773.79  390617690  3999876683313
# 2021-06-08  30773.15  30880.77  30588.81  30646.31  706548595  4795804523892
# 2021-06-09  30546.08  30567.66  30214.83  30214.83  483387763  4041239477690
# 2021-06-10  30218.08  30332.01  30114.09  30207.52  354478021  3943026195616
# 2021-06-11  30221.10  30576.77  30221.10  30518.08  251485407  3864539909864
# 2021-06-14  30500.29  30500.29  30318.18  30393.49  134271277  2505403994589
# 2021-06-15  30413.17  30688.48  30413.17  30609.84  373874551  3262372478935
# 2021-06-16  30608.97  30893.66  30608.97  30880.75  346278462  3367755468217
# 2021-06-17  30876.56  30876.56  30418.65  30546.91  390811401  3266789231770
# 2021-06-18  30555.61  30700.82  30482.91  30524.87  200640784  3427372833310
# 2021-06-21  30505.63  30505.63  30133.07  30307.43  300260775  3998435757730
# 2021-06-22  30313.19  30477.76  30275.18  30349.46  466479348  3680912732793
# 2021-06-23  30349.04  30504.22  30317.38  30414.21  290851227  3611593632096
# 2021-06-24  30487.67  30893.38  30472.53  30840.31  336091841  4408627600009
# 2021-06-25  30904.61  31138.12  30891.54  31030.79  252437761  3196514354793
# 2021-06-28  31059.17  31147.13  30877.18  30978.01  101839990  2472217682705
# 2021-06-29  31013.34  31080.76  30664.56  30745.04  115520518  2911262345845
# 2021-06-30  30764.46  31036.58  30764.46  30846.29   91190866  3024632368646
# 2021-07-01  30859.01  30870.75  30646.03  30680.64   95414744  3064729183327

# %%
# get_index_ohlcv_by_date() 함수에 frequency 파라미터(d/m/y)를 추가 rksmd
# d는 일자, m은 월, y는 연도를 의미

df = stock.get_index_ohlcv_by_date("20210101", "202106030", "1013", "m")
print(df.head())
# Out:
#                   시가        고가        저가        종가         거래량
# 날짜
# 2021-01-31  29793.56  35271.50  29793.56  30849.19  4498806152
# 2021-02-28  30849.24  32762.32  30341.24  31278.98  2723331288
# 2021-03-31  31294.71  32477.33  30089.66  30724.75  2053732804
# 2021-04-30  31010.38  32538.56  30576.85  30626.15  2528155211
# 2021-05-31  30624.48  31244.39  29072.96  30169.07  2029219840

# %%
# 인덱스 등락률 조회

#get_index_price_change_by_ticker() 함수는 지수의 등락률/거래량/거래대금을 반환
# KRX / KOSPI / KOSDAQ 세 개의 지수를 지원

df = stock.get_index_price_change_by_ticker("20210101", "20210630", "KOSDAQ")
print(df.head())
# Out:
#                         시가       종가        등락률           거래량              거래대금
# 지수명
# 코스닥                 968.42  1029.96   6.351562  271152394443  1476958803219536
# 코스닥 150            1532.52  1464.08  -4.468750   12266377117   348535041006838
# 코스닥 150 정보기술        812.05   840.79   3.539062    4261931849    82919528005520
# 코스닥 150 헬스케어       5578.37  4516.31 -19.046875    2219363960   130789715876673
# 코스닥 150 커뮤니케이션서비스  2684.58  3169.51  18.062500     575556345    31802552690080

# %% [markdown]
# ### 4.  yfinance

# %%
import yfinance as yf

# %%
# yahoo finance
# 코스피 종목에는 .KS, 코스닥 종목에는 .KQ를 붙여줘야 함
# 가장 다양한 정보 확인 가능 - 배당정보, 분할정보, 재무정보 등
# 2000년 데이터부터 조회 가능
# end에 설정한 일자의 전일자까지 조회되기 때문에 조회하고자 하는 종료일+1일을 end에 넣어줘야함
# 분단위 데이터도 조회 가능하지만 조회 가능한 기간에 제한이 있음

# %%
# yfinance --user  설치하기
# !pip install yfinance --user

# %%
import yfinance as yf

ticker = yf.Ticker('005930.KS')
 
ticker.history(
               interval='1d',
               start=start_date,
               end='2022-03-24',
               actions=True,
               auto_adjust=True)
# Out:
#                     Open          High           Low         Close    Volume  \
# Date
# 2022-01-04  77918.334260  78313.858799  77423.928586  77819.453125  12427416
# 2022-01-05  77918.327964  78116.090217  75545.180919  76533.992188  25470640
# 2022-01-06  75841.823685  76731.753820  75742.942559  76039.585938  12931954
# 2022-01-07  77226.167415  77522.810824  76533.999461  77423.929688  15163757
# 2022-01-10  77226.170202  77226.170202  76237.358804  77127.289062   9947422
# 2022-01-11  77522.805292  78116.092067  77127.280775  78017.210938  13221123
# 2022-01-12  78610.497713  78709.378842  77720.567550  78017.210938  11000502
# 2022-01-13  78412.734225  78412.734225  77028.398438  77028.398438  13889401
# 2022-01-14  76830.641727  77226.166266  76237.354918  76435.117188  10096725
# 2022-01-17  76731.763952  76929.526230  76039.595978  76632.882812   8785122
# 2022-01-18  76731.755519  76929.517776  75742.944237  76138.468750   9592788
# 2022-01-19  75644.066954  76039.591487  75248.542421  75446.304688  10598290
# 2022-01-20  75347.419118  75841.824755  75050.775735  75644.062500   9708168
# 2022-01-21  74951.902902  74951.902902  73864.210379  74754.140625  15774888
# 2022-01-24  74556.377788  74951.902339  73864.209824  74259.734375  13691134
# 2022-01-25  73963.088133  74160.850401  72380.989992  73172.039062  17766704
# 2022-01-26  73172.039062  73172.039062  73172.039062  73172.039062         0
# 2022-01-27  72974.278401  73172.040673  70502.250000  70502.250000  22274777
# 2022-01-28  70502.252217  72875.399557  70403.371078  72479.875000  21367447
# 2022-02-03  74061.973226  74061.973226  72479.875000  72479.875000  17744721
# 2022-02-04  73468.682464  73765.325866  72578.752259  73172.039062  12730034
# 2022-02-07  72677.632224  72776.513356  71589.939769  72183.226562  14240838
# 2022-02-08  72183.226562  72183.226562  72183.226562  72183.226562         0
# 2022-02-10  74754.137268  74951.899536  73864.207062  74556.375000  17746033
# 2022-02-11  74160.849883  74655.255549  73765.325350  74061.968750  12205407
# 2022-02-14  73567.566401  73666.447539  72282.111612  72875.398438  13993255
# 2022-02-15  73270.922988  73369.804126  72282.111612  72875.398438   9320365
# 2022-02-16  73765.323676  74061.967068  73369.799152  73963.085938  10767386
# 2022-02-17  74160.851562  74754.138375  73666.445885  74160.851562  13605382
# 2022-02-18  73765.323078  73963.085338  72875.392907  73468.679688  10122226
# 2022-02-21  73468.679688  73468.679688  73468.679688  73468.679688         0
# 2022-02-24  71491.056851  71491.056851  70502.245553  70700.007812  15759283
# 2022-02-25  71293.301341  71787.707037  71095.539062  71095.539062  13168484
# 2022-02-28  71095.539062  71095.539062  71095.539062  71095.539062         0
# 2022-03-02  71491.052367  71589.933490  70700.003378  70897.765625  12481430
# 2022-03-03  71491.056970  72282.106010  71392.175840  72084.343750  13232638
# 2022-03-04  72084.343750  72084.343750  72084.343750  72084.343750         0
# 2022-03-07  69216.790745  69810.077523  69117.909616  69315.671875  18617138
# 2022-03-08  68030.222662  69216.796313  67931.341524  68722.390625  15828269
# 2022-03-10  68722.390625  68722.390625  68722.390625  68722.390625         0
# 2022-03-11  69711.202567  69908.964844  68920.153460  69216.796875  15787655
# 2022-03-14  69216.792423  69414.554688  68821.267895  69414.554688   9040993
# 2022-03-15  69414.554688  69414.554688  69414.554688  69414.554688         0
# 2022-03-16  69414.558039  69711.201449  68920.152355  69612.320312  10175750
# 2022-03-17  69612.320312  69612.320312  69612.320312  69612.320312         0
# 2022-03-18  69810.079805  70106.723203  69414.555273  69908.960938  14410038
# 2022-03-21  70106.725422  70205.606558  69117.914062  69117.914062  11169002
# 2022-03-22  69117.912962  69711.199769  69117.912962  69513.437500   9402666
# 2022-03-23  69810.084264  70403.371099  69513.440847  69711.203125  12398025
#
#             Dividends  Stock Splits
# Date
# 2022-01-04          0             0
# 2022-01-05          0             0
# 2022-01-06          0             0
# 2022-01-07          0             0
# 2022-01-10          0             0
# 2022-01-11          0             0
# 2022-01-12          0             0
# 2022-01-13          0             0
# 2022-01-14          0             0
# 2022-01-17          0             0
# 2022-01-18          0             0
# 2022-01-19          0             0
# 2022-01-20          0             0
# 2022-01-21          0             0
# 2022-01-24          0             0
# 2022-01-25          0             0
# 2022-01-26          0             0
# 2022-01-27          0             0
# 2022-01-28          0             0
# 2022-02-03          0             0
# 2022-02-04          0             0
# 2022-02-07          0             0
# 2022-02-08          0             0
# 2022-02-10          0             0
# 2022-02-11          0             0
# 2022-02-14          0             0
# 2022-02-15          0             0
# 2022-02-16          0             0
# 2022-02-17          0             0
# 2022-02-18          0             0
# 2022-02-21          0             0
# 2022-02-24          0             0
# 2022-02-25          0             0
# 2022-02-28          0             0
# 2022-03-02          0             0
# 2022-03-03          0             0
# 2022-03-04          0             0
# 2022-03-07          0             0
# 2022-03-08          0             0
# 2022-03-10          0             0
# 2022-03-11          0             0
# 2022-03-14          0             0
# 2022-03-15          0             0
# 2022-03-16          0             0
# 2022-03-17          0             0
# 2022-03-18          0             0
# 2022-03-21          0             0
# 2022-03-22          0             0
# 2022-03-23          0             0

# %%
# 분단위 데이터 조회. 조회할 수 있는 기간에 제한이 있음
# 

df_minute = ticker.history(
               interval='1m',
               start='2022-09-20',
               end='2022-09-22',
               actions=True,
               auto_adjust=True)
df_minute
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2022-09-20 09:00:00+09:00  56400.0  56800.0  56400.0  56700.0       0
# 2022-09-20 09:01:00+09:00  56700.0  56800.0  56700.0  56700.0   66613
# 2022-09-20 09:02:00+09:00  56700.0  56800.0  56600.0  56600.0   80712
# 2022-09-20 09:03:00+09:00  56700.0  56800.0  56600.0  56700.0  298720
# 2022-09-20 09:04:00+09:00  56800.0  56900.0  56700.0  56800.0  137690
# ...                            ...      ...      ...      ...     ...
# 2022-09-21 14:55:00+09:00  55300.0  55300.0  55200.0  55300.0   21357
# 2022-09-21 14:56:00+09:00  55200.0  55300.0  55200.0  55300.0   66540
# 2022-09-21 14:57:00+09:00  55300.0  55300.0  55200.0  55300.0    8660
# 2022-09-21 14:58:00+09:00  55200.0  55300.0  55200.0  55300.0    7628
# 2022-09-21 14:59:00+09:00  55300.0  55300.0  55200.0  55300.0   15058
#
#                            Dividends  Stock Splits
# Datetime
# 2022-09-20 09:00:00+09:00          0             0
# 2022-09-20 09:01:00+09:00          0             0
# 2022-09-20 09:02:00+09:00          0             0
# 2022-09-20 09:03:00+09:00          0             0
# 2022-09-20 09:04:00+09:00          0             0
# ...                              ...           ...
# 2022-09-21 14:55:00+09:00          0             0
# 2022-09-21 14:56:00+09:00          0             0
# 2022-09-21 14:57:00+09:00          0             0
# 2022-09-21 14:58:00+09:00          0             0
# 2022-09-21 14:59:00+09:00          0             0
#
# [716 rows x 7 columns]

# %%
# 애플 주가 가져오기

import yfinance as yf

yf.download('AAPL', start = '2018-12-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-11-30   45.072498   45.082500   44.257500   44.645000   43.161751
# 2018-12-03   46.115002   46.235001   45.302502   46.205002   44.669930
# 2018-12-04   45.237499   45.597500   44.067501   44.172501   42.704952
# 2018-12-06   42.939999   43.695000   42.605000   43.680000   42.228806
# 2018-12-07   43.372501   43.622501   42.075001   42.122501   40.723064
# ...                ...         ...         ...         ...         ...
# 2022-09-23  151.190002  151.470001  148.559998  150.429993  150.429993
# 2022-09-26  149.660004  153.770004  149.639999  150.770004  150.770004
# 2022-09-27  152.740005  154.720001  149.949997  151.759995  151.759995
# 2022-09-28  147.639999  150.639999  144.839996  149.839996  149.839996
# 2022-09-29  146.100006  146.720001  140.679993  142.479996  142.479996
#
#                Volume
# Date
# 2018-11-30  158126000
# 2018-12-03  163210000
# 2018-12-04  165377200
# 2018-12-06  172393600
# 2018-12-07  169126400
# ...               ...
# 2022-09-23   95939200
# 2022-09-26   93339400
# 2022-09-27   84442700
# 2022-09-28  146691400
# 2022-09-29  127977800
#
# [964 rows x 6 columns]

# %% [markdown]
# ## 심볼보기
# ### https://github.com/financedata-org/FinanceDataReader/wiki/Quick-Reference

# %%
# 한국 주요 지수
# 미국 주요 지수
# 국가별 대표 지수
# 상품선물
# 환율
# 채권 수익률 등

# %%
import FinanceDataReader as fdr

sp500 = fdr.StockListing('S&P500')
sp500.head(10)
# Out:
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\FinanceDataReader\wikipedia\listing.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Symbol'] = df['Symbol'].str.replace('\.', '')
#   Symbol                 Name                  Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT               Abbott             Health Care
# 3   ABBV               AbbVie             Health Care
# 4   ABMD              Abiomed             Health Care
# 5    ACN            Accenture  Information Technology
# 6   ATVI  Activision Blizzard  Communication Services
# 7    ADM                  ADM        Consumer Staples
# 8   ADBE           Adobe Inc.  Information Technology
# 9    ADP                  ADP  Information Technology
#
#                                 Industry
# 0               Industrial Conglomerates
# 1                      Building Products
# 2                  Health Care Equipment
# 3                        Pharmaceuticals
# 4                  Health Care Equipment
# 5         IT Consulting & Other Services
# 6         Interactive Home Entertainment
# 7                  Agricultural Products
# 8                   Application Software
# 9  Data Processing & Outsourced Services

# %%
# S&P500 종목은 실제 503개
len(sp500)
# Out:
# 503

# %%
# Indexes: 'KS11'(코스피지수), 'KQ11'(코스닥지수), 'DJI'(다우존스지수), 'IXIC'(나스닥지수), 'US500'(S&P 500지수) ...

# %%
# Exchanges: 'USD/KRX', 'USD/EUR', 'CNY/KRW' ... (조합가능한 화폐별 환율 데이터 일자별)
